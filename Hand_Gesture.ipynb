# %%
pip install opencv-python mediapipe pyautogui
# Out:
# Requirement already satisfied: opencv-python in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (4.10.0.84)
# Requirement already satisfied: mediapipe in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (0.10.14)
# Requirement already satisfied: pyautogui in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (0.9.54)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from opencv-python) (2.0.1)
# Requirement already satisfied: absl-py in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from mediapipe) (2.1.0)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from mediapipe) (24.2.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from mediapipe) (24.3.25)
# Requirement already satisfied: jax in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from mediapipe) (0.4.31)
# Requirement already satisfied: jaxlib in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from mediapipe) (0.4.31)
# Requirement already satisfied: matplotlib in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from mediapipe) (3.9.2)
# Requirement already satisfied: opencv-contrib-python in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from mediapipe) (4.10.0.84)
# Requirement already satisfied: protobuf<5,>=4.25.3 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from mediapipe) (4.25.4)
# Requirement already satisfied: sounddevice>=0.4.4 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from mediapipe) (0.5.0)
# Requirement already satisfied: pymsgbox in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from pyautogui) (1.0.9)
# Requirement already satisfied: pytweening>=1.0.4 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from pyautogui) (1.2.0)
# Requirement already satisfied: pyscreeze>=0.1.21 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from pyautogui) (0.1.30)
# Requirement already satisfied: pygetwindow>=0.0.5 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from pyautogui) (0.0.9)
# Requirement already satisfied: mouseinfo in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from pyautogui) (0.1.3)
# Requirement already satisfied: pyrect in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from pygetwindow>=0.0.5->pyautogui) (0.2.0)
# Requirement already satisfied: CFFI>=1.0 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from sounddevice>=0.4.4->mediapipe) (1.17.0)
# Requirement already satisfied: ml-dtypes>=0.2.0 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from jax->mediapipe) (0.4.0)
# Requirement already satisfied: opt-einsum in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from jax->mediapipe) (3.3.0)
# Requirement already satisfied: scipy>=1.10 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from jax->mediapipe) (1.14.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mediapipe) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mediapipe) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mediapipe) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\sayan\appdata\roaming\python\python312\site-packages (from matplotlib->mediapipe) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mediapipe) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mediapipe) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sayan\appdata\roaming\python\python312\site-packages (from matplotlib->mediapipe) (2.9.0.post0)
# Requirement already satisfied: pyperclip in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from mouseinfo->pyautogui) (1.9.0)
# Requirement already satisfied: pycparser in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.22)
# Requirement already satisfied: six>=1.5 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Import Libraries and Set Up Hand Detection

# %%
import cv2
import mediapipe as mp
import pyautogui
import time
import numpy as np
from collections import deque

# Initialize Mediapipe hand detection with higher confidence thresholds
mp_hands = mp.solutions.hands
hands = mp_hands.Hands(max_num_hands=1, min_detection_confidence=0.8, min_tracking_confidence=0.8)
mp_draw = mp.solutions.drawing_utils

# Variables for delay management
last_play_pause_time = time.time()
last_volume_change_time = time.time()
last_gesture_time = time.time()

# Thresholds
play_pause_delay = 1  # 1 second delay for play/pause
volume_change_delay = 0.2  # 1/5 second delay for volume change
gesture_delay = 1  # 1 second delay for gestures
movement_threshold = 0.005  # adjust threshold for detecting meaningful fist movements

# Gesture States
is_open_palm = False
is_fist = False
previous_fist_position = None

# Frame rate control
target_fps = 24
frame_duration = 1.0 / target_fps

# Smoothing settings
smoothing_window_size = 5
landmark_queue = deque(maxlen=smoothing_window_size)

# Capture video from webcam
cap = cv2.VideoCapture(0)

def is_open_palm_landmarks(landmarks):
    return landmarks[8][1] < landmarks[6][1] and \
           landmarks[12][1] < landmarks[10][1] and \
           landmarks[16][1] < landmarks[14][1] and \
           landmarks[20][1] < landmarks[18][1]

def is_fist_landmarks(landmarks):
    return landmarks[8][1] > landmarks[6][1] and \
           landmarks[12][1] > landmarks[10][1] and \
           landmarks[16][1] > landmarks[14][1] and \
           landmarks[20][1] > landmarks[18][1]

def is_index_finger_pointing_up(landmarks):
    return landmarks[8][1] < landmarks[6][1] and \
           landmarks[12][1] > landmarks[10][1] and \
           landmarks[16][1] > landmarks[14][1] and \
           landmarks[20][1] > landmarks[18][1]

def is_thumb_down(landmarks):
    return landmarks[4][1] > landmarks[3][1] and \
           landmarks[8][1] < landmarks[6][1] and \
           landmarks[12][1] < landmarks[10][1] and \
           landmarks[16][1] < landmarks[14][1] and \
           landmarks[20][1] < landmarks[18][1]

def get_fist_direction(current_position, previous_position):
    if current_position is not None and previous_position is not None:
        x_movement = current_position[0] - previous_position[0]
        print(f"X movement: {x_movement}")  # Debugging: print movement amount
        if abs(x_movement) > movement_threshold:
            if x_movement < 0:
                print("Fist moved left")
                return "left"
            elif x_movement > 0:
                print("Fist moved right")
                return "right"
    return None

def smooth_landmarks(landmarks):
    landmark_queue.append(landmarks)
    avg_landmarks = np.mean(landmark_queue, axis=0)
    return avg_landmarks

while cap.isOpened():
    start_time = time.time()

    success, frame = cap.read()
    if not success:
        print("Failed to capture frame")
        break
    
    # Convert the image to RGB
    image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    image.flags.writeable = False
    
    # Process the image and detect hands
    results = hands.process(image)
    image.flags.writeable = True
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    
    if results.multi_hand_landmarks:
        for hand_landmarks in results.multi_hand_landmarks:
            # Convert landmarks to numpy array for smoothing
            landmarks_array = np.array([(lm.x, lm.y, lm.z) for lm in hand_landmarks.landmark])
            
            # Smooth the landmarks
            smoothed_landmarks = smooth_landmarks(landmarks_array)
            
            # Check if the hand is open palm
            if is_open_palm_landmarks(smoothed_landmarks):
                if not is_open_palm and (time.time() - last_play_pause_time) > play_pause_delay:
                    print("Open palm detected: Play/Pause triggered")
                    pyautogui.press('space')
                    last_play_pause_time = time.time()
                    is_open_palm = True
                is_fist = False  # Reset fist status
            else:
                is_open_palm = False
            
            # Check if the hand is in a fist
            if is_fist_landmarks(smoothed_landmarks):
                print("Fist detected")
                current_position = smoothed_landmarks[9]  # Use landmark 9 as reference for fist position
                if is_fist and previous_fist_position is not None:
                    direction = get_fist_direction(current_position, previous_fist_position)
                    if direction == "left" and (time.time() - last_volume_change_time) > volume_change_delay:
                        print("Volume Down triggered")
                        pyautogui.press('volumedown')
                        last_volume_change_time = time.time()
                    elif direction == "right" and (time.time() - last_volume_change_time) > volume_change_delay:
                        print("Volume Up triggered")
                        pyautogui.press('volumeup')
                        last_volume_change_time = time.time()
                is_fist = True
                previous_fist_position = current_position  # Update the previous fist position
            else:
                is_fist = False

            # Check for index finger pointing up
            if is_index_finger_pointing_up(smoothed_landmarks) and (time.time() - last_gesture_time) > gesture_delay:
                print("Index finger up detected: Fast forward 5 secs")
                pyautogui.press('right')
                last_gesture_time = time.time()

            # Check for thumb down
            if is_thumb_down(smoothed_landmarks) and (time.time() - last_gesture_time) > gesture_delay:
                print("Thumb down detected: Rewind 5 secs")
                pyautogui.press('left')
                last_gesture_time = time.time()

            # Draw hand landmarks
            mp_draw.draw_landmarks(image, hand_landmarks, mp_hands.HAND_CONNECTIONS)
    
    # Display the video feed
    cv2.imshow('Hand Gesture Control', image)
    
    # Break loop with 'q' key
    if cv2.waitKey(1) & 0xFF == ord('q'):
        print("Quitting program")
        break

    # Frame rate control
    end_time = time.time()
    elapsed_time = end_time - start_time
    if elapsed_time < frame_duration:
        time.sleep(frame_duration - elapsed_time)

cap.release()
cv2.destroyAllWindows()
# Out:
# Open palm detected: Play/Pause triggered
# Index finger up detected: Fast forward 5 secs
# Index finger up detected: Fast forward 5 secs
# Index finger up detected: Fast forward 5 secs
# Index finger up detected: Fast forward 5 secs
# Fist detected
# Fist detected
# X movement: -0.004591739177703835
# Fist detected
# X movement: -0.004750436544418368
# Fist detected
# X movement: -0.0017773985862731823
# Fist detected
# X movement: -0.001065969467163086
# Fist detected
# X movement: -0.0009798467159271018
# Fist detected
# X movement: 0.00032973289489746094
# Fist detected
# X movement: 7.787942886350319e-05
# Fist detected
# X movement: -8.02934169769065e-05
# Fist detected
# X movement: -0.00036832690238952637
# Fist detected
# X movement: -0.00031139254570006214
# Fist detected
# X movement: -0.00023632049560551316
# Fist detected
# X movement: 0.00011552572250367321
# Fist detected
# X movement: -3.1620264053344727e-05
# Fist detected
# X movement: 0.0003204762935638539
# Fist detected
# X movement: 0.0003007471561431996
# Fist detected
# X movement: -2.0104646682728156e-05
# Fist detected
# X movement: 0.00026143789291377395
# Fist detected
# X movement: 0.00024808645248414196
# Fist detected
# X movement: 0.00019194483757017933
# Fist detected
# X movement: -0.00014571547508235305
# Fist detected
# X movement: 0.00012139678001399368
# Fist detected
# X movement: -0.00030707716941830165
# Fist detected
# X movement: -0.00035877227783204235
# Fist detected
# X movement: -0.00036426782608034447
# Fist detected
# X movement: -0.0003219902515411155
# Fist detected
# X movement: -0.00019064545631408691
# Fist detected
# X movement: -0.00031759142875670276
# Fist detected
# X movement: -0.0001818239688873291
# Fist detected
# X movement: -0.0004794001579284668
# Fist detected
# X movement: -9.015798568728917e-05
# Fist detected
# X movement: -0.00038257837295530006
# Fist detected
# X movement: -0.00011463761329649769
# Fist detected
# X movement: 4.989504814145729e-05
# Fist detected
# X movement: 0.0003878057003021129
# Fist detected
# X movement: 0.0002813398838043546
# Fist detected
# X movement: 0.0002965688705444114
# Fist detected
# X movement: 0.0003519594669342263
# Fist detected
# X movement: -0.0001631319522857888
# Fist detected
# X movement: -0.0002487957477569358
# Fist detected
# X movement: -0.00033806562423704944
# Fist detected
# X movement: -0.0002048492431641069
# Fist detected
# X movement: -0.00036305785179135963
# Fist detected
# X movement: -5.1867961883556024e-05
# Fist detected
# X movement: -2.8896331787098273e-05
# Fist detected
# X movement: 0.00010712146759034313
# Fist detected
# X movement: -1.3160705566395148e-05
# Fist detected
# X movement: -7.530450820925072e-05
# Fist detected
# X movement: -0.001358628273010254
# Fist detected
# X movement: -0.017439770698547352
# Fist moved left
# Volume Down triggered
# Fist detected
# X movement: -0.013797831535339367
# Fist moved left
# Open palm detected: Play/Pause triggered
# Index finger up detected: Fast forward 5 secs
# Fist detected
# Fist detected
# X movement: -5.165934562684216e-05
# Fist detected
# X movement: -0.000997340679168679
# Fist detected
# X movement: -0.0005622446537018044
# Fist detected
# X movement: -0.0003643035888671875
# Fist detected
# X movement: -0.0002842426300048717
# Fist detected
# X movement: -0.000172013044357322
# Fist detected
# X movement: 0.0006481409072875977
# Fist detected
# X movement: 0.000616186857223533
# Fist detected
# X movement: 0.0006676018238067627
# Fist detected
# X movement: -0.0010283470153808483
# Fist detected
# X movement: -0.0013839483261108287
# Fist detected
# X movement: -0.0015723288059235063
# Open palm detected: Play/Pause triggered
# Thumb down detected: Rewind 5 secs
# Thumb down detected: Rewind 5 secs
# Thumb down detected: Rewind 5 secs
# Thumb down detected: Rewind 5 secs
# Fist detected
# Fist detected
# X movement: 0.01078265011310578
# Fist moved right
# Volume Up triggered
# Fist detected
# X movement: 0.002716335654258717
# Fist detected
# X movement: 0.0029279381036758367
# Fist detected
# X movement: 0.0027529060840606745
# Fist detected
# X movement: -0.0013375580310821533
# Fist detected
# X movement: 0.00024868547916412354
# Fist detected
# X movement: 0.0010019361972808949
# Fist detected
# X movement: 0.0008157849311828391
# Fist detected
# X movement: 0.0004931151866912897
# Fist detected
# X movement: 0.0004100322723388783
# Fist detected
# X movement: 0.0003894358873367254
# Fist detected
# X movement: 0.0001335918903350719
# Fist detected
# X movement: 0.0006395757198333907
# Fist detected
# X movement: 0.0008189857006072887
# Fist detected
# X movement: 0.0009558558464050348
# Fist detected
# X movement: 0.0007677942514419667
# Fist detected
# X movement: 0.00033914744853971723
# Fist detected
# X movement: 5.1814317703263724e-05
# Fist detected
# X movement: -8.029341697693426e-05
# Fist detected
# X movement: -0.00028702616691589355
# Fist detected
# X movement: -0.00040753781795502264
# Fist detected
# X movement: -4.625022411347546e-05
# Fist detected
# X movement: -3.10748815536277e-05
# Fist detected
# X movement: 0.00010254085063932106
# Fist detected
# X movement: 8.365213871003307e-05
# Fist detected
# X movement: 0.00025625526905059814
# Fist detected
# X movement: 0.0003572762012481745
# Fist detected
# X movement: -0.0009583264589309859
# Fist detected
# X movement: 0.0035936146974563654
# Fist detected
# X movement: 0.004086253046989452
# Fist detected
# X movement: 0.004316696524620051
# Fist detected
# X movement: 0.004339089989662148
# Fist detected
# X movement: 0.005542010068893433
# Fist moved right
# Volume Up triggered
# Fist detected
# X movement: 0.004413050413131725
# Fist detected
# X movement: 0.0032961487770080677
# Fist detected
# X movement: 0.006629991531372059
# Fist moved right
# Fist detected
# X movement: 0.008146327733993541
# Fist moved right
# Volume Up triggered
# Fist detected
# X movement: 0.008117383718490578
# Fist moved right
# Fist detected
# X movement: 0.009847640991210938
# Fist moved right
# Fist detected
# X movement: 0.00948820710182191
# Fist moved right
# Fist detected
# X movement: 0.010111016035079967
# Fist moved right
# Fist detected
# X movement: 0.010247731208801292
# Fist moved right
# Volume Up triggered
# Fist detected
# X movement: 0.012114810943603505
# Fist moved right
# Fist detected
# X movement: 0.0072504222393035556
# Fist moved right
# Fist detected
# X movement: 0.00810540318489078
# Fist moved right
# Fist detected
# X movement: 0.005810493230819669
# Fist moved right
# Fist detected
# X movement: 0.005528712272644065
# Fist moved right
# Volume Up triggered
# Fist detected
# X movement: 0.004405629634857189
# Fist detected
# X movement: 0.004422819614410378
# Fist detected
# X movement: 0.004449659585952781
# Fist detected
# X movement: 0.004402232170104992
# Fist detected
# X movement: 0.0031025290489196666
# Fist detected
# X movement: 0.002043122053146329
# Fist detected
# X movement: 0.0035011053085327593
# Fist detected
# X movement: 0.006237232685089078
# Fist moved right
# Volume Up triggered
# Fist detected
# X movement: 0.006724512577056918
# Fist moved right
# Fist detected
# X movement: 0.006218481063842762
# Fist moved right
# Fist detected
# X movement: 0.006317591667175271
# Fist moved right
# Fist detected
# X movement: 0.005833679437637351
# Fist moved right
# Fist detected
# X movement: 0.003127354383468617
# Fist detected
# X movement: 0.0009311497211456077
# Fist detected
# X movement: 0.0018983364105225053
# Fist detected
# X movement: 0.0032299399375915194
# Fist detected
# X movement: 0.0021268725395202637
# Fist detected
# X movement: 0.0020736277103424183
# Fist detected
# X movement: 0.0020759105682373047
# Fist detected
# X movement: 0.0017026126384734885
# Fist detected
# X movement: 0.0006586432456970326
# Fist detected
# X movement: 0.00035272836685179554
# Fist detected
# X movement: 0.00047528743743896484
# Fist detected
# X movement: -0.0006523251533507857
# Fist detected
# X movement: -0.0008444786071777344
# Fist detected
# X movement: -0.0010510683059692383
# Fist detected
# X movement: -0.002361637353897106
# Fist detected
# X movement: -0.0022841691970825195
# Fist detected
# X movement: -0.001219332218170166
# Fist detected
# X movement: -0.0013456404209137296
# Fist detected
# X movement: -0.0038459062576293723
# Fist detected
# X movement: -0.0022650837898254284
# Fist detected
# X movement: -0.003969717025756825
# Fist detected
# X movement: -0.00402185320854187
# Fist detected
# X movement: -0.006071412563323997
# Fist moved left
# Volume Down triggered
# Fist detected
# X movement: -0.003676050901412986
# Fist detected
# X movement: -0.00594612360000607
# Fist moved left
# Fist detected
# X movement: -0.004133290052413974
# Fist detected
# X movement: -0.006178241968154863
# Fist moved left
# Fist detected
# X movement: -0.006014680862426791
# Fist moved left
# Volume Down triggered
# Fist detected
# X movement: -0.0074316799640655185
# Fist moved left
# Fist detected
# X movement: -0.005199015140533447
# Fist moved left
# Fist detected
# X movement: -0.005733299255371138
# Fist moved left
# Fist detected
# X movement: -0.005087912082672119
# Fist moved left
# Fist detected
# X movement: -0.0030736148357390913
# Fist detected
# X movement: -0.0018079042434692716
# Fist detected
# X movement: -0.0036369740962982067
# Fist detected
# X movement: -0.007396191358566284
# Fist moved left
# Volume Down triggered
# Fist detected
# X movement: -0.006924206018447898
# Fist moved left
# Fist detected
# X movement: -0.006978732347488359
# Fist moved left
# Fist detected
# X movement: -0.006420236825943004
# Fist moved left
# Fist detected
# X movement: -0.00608195662498473
# Fist moved left
# Fist detected
# X movement: -0.004030764102935791
# Fist detected
# X movement: -0.0026003181934357023
# Fist detected
# X movement: -0.002451503276824918
# Fist detected
# X movement: -0.004345858097076438
# Fist detected
# X movement: -0.0028359174728393444
# Fist detected
# X movement: -0.0005914688110351674
# Fist detected
# X movement: -0.0010991871356964
# Fist detected
# X movement: -0.004666775465011597
# Fist detected
# X movement: -0.002712976932525646
# Fist detected
# X movement: -0.00459560751914978
# Fist detected
# X movement: -0.004062432050704945
# Fist detected
# X movement: -0.006910085678100586
# Fist moved left
# Volume Down triggered
# Fist detected
# X movement: -0.0029218733310699685
# Fist detected
# X movement: -0.005078220367431607
# Fist moved left
# Fist detected
# X movement: -0.0030704379081726296
# Fist detected
# X movement: -0.005244177579879772
# Fist moved left
# Fist detected
# X movement: -0.004540616273879972
# Fist detected
# X movement: -0.004959928989410445
# Fist detected
# X movement: -0.003409507870674122
# Fist detected
# X movement: -0.005160620808601357
# Fist moved left
# Volume Down triggered
# Fist detected
# X movement: -0.005447855591773992
# Fist moved left
# Fist detected
# X movement: -0.003437650203704845
# Fist detected
# X movement: -0.0031677186489105225
# Fist detected
# X movement: -0.005013960599899281
# Fist moved left
# Fist detected
# X movement: -0.006195193529129034
# Fist moved left
# Volume Down triggered
# Fist detected
# X movement: -0.004318067431449885
# Fist detected
# X movement: -0.007338714599609386
# Fist moved left
# Fist detected
# X movement: -0.0072937458753585815
# Fist moved left
# Fist detected
# X movement: -0.007272112369537342
# Fist moved left
# Fist detected
# X movement: -0.005674475431442255
# Fist moved left
# Volume Down triggered
# Fist detected
# X movement: -0.006153121590614319
# Fist moved left
# Fist detected
# X movement: -0.0030221939086914062
# Fist detected
# X movement: -0.0034669876098633035
# Fist detected
# X movement: -0.0023472219705581443
# Fist detected
# X movement: -0.0010109782218933328
# Fist detected
# X movement: -0.0007381021976470836
# Fist detected
# X movement: -0.0005713611841201838
# Fist detected
# X movement: -0.0014420002698898315
# Fist detected
# X movement: -0.0005391299724578913
# Fist detected
# X movement: -0.00091644227504728
# Fist detected
# X movement: -0.0009740263223648182
# Fist detected
# X movement: -0.0010846465826034601
# Fist detected
# X movement: -0.0002959460020065252
# Fist detected
# X movement: -0.00046458542346955456
# Fist detected
# X movement: -0.0004456549882888572
# Fist detected
# X movement: -0.0004808753728866577
# Fist detected
# X movement: -0.0005575656890869363
# Fist detected
# X movement: -0.000477993488311762
# Fist detected
# X movement: -0.00017856359481810413
# Fist detected
# X movement: 4.5546889305109195e-05
# Fist detected
# X movement: 0.00010381639003753662
# Fist detected
# X movement: 0.00030644834041596014
# Fist detected
# X movement: 0.0005744129419326671
# Fist detected
# X movement: 0.0004120469093322754
# Fist detected
# X movement: 0.0002579152584075983
# Fist detected
# X movement: 0.00039165914058686413
# Fist detected
# X movement: 0.00047576725482939564
# Fist detected
# X movement: 0.0004687577486038319
# Fist detected
# X movement: 0.0005757272243499534
# Fist detected
# X movement: 0.0012640058994293213
# Fist detected
# X movement: 0.001358544826507574
# Fist detected
# X movement: 0.001486161351203913
# Fist detected
# X movement: 0.0013586223125457986
# Fist detected
# X movement: 0.0014395803213119451
# Fist detected
# X movement: 0.0011342078447341974
# Fist detected
# X movement: 0.00127408206462859
# Fist detected
# X movement: 0.001234334707260143
# Fist detected
# X movement: 0.0009589791297912598
# Fist detected
# X movement: 0.001202869415283192
# Fist detected
# X movement: 0.0007169097661972046
# Fist detected
# X movement: 0.0003891170024871715
# Fist detected
# X movement: 0.00010778903961183861
# Fist detected
# X movement: 0.0002751618623733354
# Fist detected
# X movement: -0.00016158819198608398
# Fist detected
# X movement: 0.0006414890289306585
# Fist detected
# X movement: 0.0010320097208023071
# Fist detected
# X movement: 0.000883853435516363
# Fist detected
# X movement: 0.0009839743375778254
# Fist detected
# X movement: 0.0010513782501220814
# Fist detected
# X movement: 0.0007624149322509599
# Fist detected
# X movement: 0.0005214691162109542
# Fist detected
# X movement: 0.0007244199514389038
# Fist detected
# X movement: 0.0004735022783279308
# Fist detected
# X movement: 0.000501289963722229
# Fist detected
# X movement: 4.7573447227472476e-05
# Fist detected
# X movement: -4.979372024535578e-05
# Fist detected
# X movement: -0.00020173192024230957
# Fist detected
# X movement: 0.00019692480564117987
# Fist detected
# X movement: 0.00023071765899657093
# Fist detected
# X movement: 0.00015462934970855713
# Fist detected
# X movement: -8.797943592070423e-05
# Fist detected
# X movement: -0.00010948181152345415
# Fist detected
# X movement: -0.00041549503803250953
# Fist detected
# X movement: -0.00045329034328461804
# Fist detected
# X movement: 0.0011636227369308527
# Fist detected
# X movement: 0.0011486470699310358
# Open palm detected: Play/Pause triggered
# Thumb down detected: Rewind 5 secs
# Thumb down detected: Rewind 5 secs
# Thumb down detected: Rewind 5 secs
# Thumb down detected: Rewind 5 secs
# Fist detected
# Fist detected
# X movement: 0.0042546093463897705
# Fist detected
# X movement: 0.0023535430431365634
# Fist detected
# X movement: 0.0018066048622131237
# Open palm detected: Play/Pause triggered
# Fist detected
# Fist detected
# X movement: 0.0005819499492645264
# Fist detected
# X movement: 0.00031819939613342285
# Open palm detected: Play/Pause triggered
# Fist detected
# Fist detected
# X movement: 0.0007895231246948242
# Fist detected
# X movement: 0.0024482131004333607
# Fist detected
# X movement: 0.003392595052719105
# Fist detected
# X movement: 0.0007099330425262562
# Fist detected
# X movement: 0.00022585391998286575
# Fist detected
# X movement: -0.0014204561710357555
# Fist detected
# X movement: -0.0022175848484038974
# Fist detected
# X movement: -0.003088146448135376
# Fist detected
# X movement: -0.003747934103012107
# Fist detected
# X movement: -0.0028037309646606334
# Fist detected
# X movement: -0.00552760362625121
# Fist moved left
# Volume Down triggered
# Fist detected
# X movement: -0.007549327611923229
# Fist moved left
# Fist detected
# X movement: -0.009456723928451538
# Fist moved left
# Fist detected
# X movement: -0.008069711923599232
# Fist moved left
# Fist detected
# X movement: -0.011013638973236095
# Fist moved left
# Volume Down triggered
# Fist detected
# X movement: -0.008811014890670765
# Fist moved left
# Fist detected
# X movement: -0.0087338387966156
# Fist moved left
# Fist detected
# X movement: -0.005137974023818992
# Fist moved left
# Volume Down triggered
# Fist detected
# X movement: -0.009327840805053722
# Fist moved left
# Fist detected
# X movement: -0.008692920207977295
# Fist moved left
# Fist detected
# X movement: -0.0064606904983520175
# Fist moved left
# Fist detected
# X movement: -0.0064719498157501665
# Fist moved left
# Volume Down triggered
# Fist detected
# X movement: -0.010131961107254006
# Fist moved left
# Fist detected
# X movement: -0.009722971916198753
# Fist moved left
# Fist detected
# X movement: -0.007961040735244729
# Fist moved left
# Fist detected
# X movement: -0.009083336591720559
# Fist moved left
# Volume Down triggered
# Fist detected
# X movement: -0.010989242792129539
# Fist moved left
# Fist detected
# X movement: -0.01182357072830198
# Fist moved left
# Fist detected
# X movement: -0.008278495073318515
# Fist moved left
# Fist detected
# X movement: -0.010882845520973183
# Fist moved left
# Volume Down triggered
# Fist detected
# X movement: -0.012514379620552074
# Fist moved left
# Volume Down triggered
# Fist detected
# X movement: -0.01358191967010497
# Fist moved left
# Fist detected
# X movement: -0.008760505914688133
# Fist moved left
# Fist detected
# X movement: 0.011677438020706199
# Fist moved right
# Volume Up triggered
# Fist detected
# X movement: 0.018381217122077936
# Fist moved right
# Fist detected
# X movement: 0.022984042763709994
# Fist moved right
# Fist detected
# X movement: 0.030656379461288463
# Fist moved right
# Fist detected
# X movement: 0.029598701000213612
# Fist moved right
# Volume Up triggered
# Fist detected
# X movement: 0.01591138839721684
# Fist moved right
# Fist detected
# X movement: 0.010596728324890115
# Fist moved right
# Fist detected
# X movement: 0.012665522098541271
# Fist moved right
# Fist detected
# X movement: 0.00820232033729551
# Fist moved right
# Volume Up triggered
# Fist detected
# X movement: 0.016368162631988536
# Fist moved right
# Fist detected
# X movement: 0.00881046652793882
# Fist moved right
# Fist detected
# X movement: 0.011716252565383944
# Fist moved right
# Fist detected
# X movement: 0.01009235978126527
# Fist moved right
# Volume Up triggered
# Fist detected
# X movement: 0.012200617790222135
# Fist moved right
# Fist detected
# X movement: 0.00392156243324282
# Fist detected
# X movement: 0.004092085361480702
# Fist detected
# X movement: 0.0019934237003326194
# Open palm detected: Play/Pause triggered
# Fist detected
# Fist detected
# X movement: 0.0010459065437317117
# Fist detected
# X movement: -0.0008765935897827037
# Fist detected
# X movement: -0.0010545194149017556
# Fist detected
# X movement: -0.0008646547794342041
# Fist detected
# X movement: -0.00040776729583741345
# Fist detected
# X movement: -0.00010825395584102004
# Fist detected
# X movement: 8.783340454099342e-05
# Fist detected
# X movement: 8.585453033449486e-05
# Fist detected
# X movement: 0.0005489706993102583
# Fist detected
# X movement: 0.0009527981281280962
# Fist detected
# X movement: 0.000875437259674039
# Fist detected
# X movement: 0.0011870324611664151
# Fist detected
# X movement: 0.0013356208801269531
# Fist detected
# X movement: 0.0010413110256194957
# Fist detected
# X movement: 0.0005464971065521351
# Fist detected
# X movement: 0.0009892225265502597
# Fist detected
# X movement: 0.0004701554775238259
# Fist detected
# X movement: 0.0005324602127075306
# Fist detected
# X movement: 0.0004368901252746471
# Fist detected
# X movement: 0.0005468428134918213
# Fist detected
# X movement: 0.00016555190086364746
# Fist detected
# X movement: 0.00011956095695492275
# Fist detected
# X movement: 0.00010319948196413353
# Fist detected
# X movement: 0.00011280179023742676
# Fist detected
# X movement: -0.00020779967308043323
# Fist detected
# X movement: -0.0001588881015777699
# Fist detected
# X movement: -0.00015138983726503685
# Fist detected
# X movement: -0.0004408121109008567
# Fist detected
# X movement: -0.0004681527614593395
# Fist detected
# X movement: -0.00029553771018980823
# Fist detected
# X movement: -0.0003337562084197998
# Fist detected
# X movement: -0.000468486547470115
# Fist detected
# X movement: -0.0005235850811004528
# Fist detected
# X movement: -0.0006292819976806974
# Fist detected
# X movement: -0.000504297018051103
# Fist detected
# X movement: -0.0006884336471557617
# Fist detected
# X movement: -0.00043892860412597656
# Fist detected
# X movement: -0.000534242391586337
# Fist detected
# X movement: -0.00045858025550843395
# Fist detected
# X movement: -0.0005302608013152965
# Fist detected
# X movement: -0.00047718286514281116
# Fist detected
# X movement: -0.0006510019302368164
# Fist detected
# X movement: -0.00019170641899107776
# Fist detected
# X movement: -0.00018327832221987084
# Fist detected
# X movement: -0.00016309022903443493
# Fist detected
# X movement: 0.00012257099151613549
# Fist detected
# X movement: 0.0001682281494140847
# Fist detected
# X movement: 0.00027950406074522816
# Fist detected
# X movement: 0.0002278923988341952
# Fist detected
# X movement: 0.0002576470375061368
# Fist detected
# X movement: 0.00014538764953614391
# Fist detected
# X movement: 0.0002579689025878906
# Fist detected
# X movement: 4.892945289608486e-05
# Fist detected
# X movement: 0.00025676488876341663
# Fist detected
# X movement: 3.2806396484397204e-05
# Fist detected
# X movement: -0.00024886131286622204
# Fist detected
# X movement: -0.00021705031394958496
# Fist detected
# X movement: -0.00031519532203672096
# Fist detected
# X movement: -0.0007885038852691872
# Index finger up detected: Fast forward 5 secs
# Index finger up detected: Fast forward 5 secs
# Index finger up detected: Fast forward 5 secs
# Index finger up detected: Fast forward 5 secs
# Fist detected
# Fist detected
# X movement: 0.0014160215854644997
# Fist detected
# X movement: 0.0005070686340331587
# Fist detected
# X movement: 0.0003143012523651456
# Fist detected
# X movement: 0.0005143165588378795
# Fist detected
# X movement: -0.0004800915718078391
# Fist detected
# X movement: 0.00021607875823970168
# Fist detected
# X movement: -0.00026863813400268555
# Fist detected
# X movement: 0.00019736289978028454
# Fist detected
# X movement: -0.0004772305488586204
# Fist detected
# X movement: -0.0001430213451385498
# Fist detected
# X movement: -0.00015438199043277256
# Fist detected
# X movement: 1.752972602847569e-05
# Fist detected
# X movement: -0.0009461462497711293
# Fist detected
# X movement: -0.0016025722026825062
# Fist detected
# X movement: -0.0014048397541046032
# Fist detected
# X movement: -0.0015913307666778342
# Fist detected
# X movement: -0.0018183171749115434
# Fist detected
# X movement: -0.0027941465377807617
# Index finger up detected: Fast forward 5 secs
# Index finger up detected: Fast forward 5 secs
# Fist detected
# Fist detected
# X movement: -0.0002639591693878174
# Fist detected
# X movement: 0.0006919085979461559
# Fist detected
# X movement: 0.00024915337562564366
# Fist detected
# X movement: 0.00024586915969848633
# Fist detected
# X movement: 0.0004296600818634033
# Fist detected
# X movement: 0.0008344829082488903
# Fist detected
# X movement: 0.0013273119926452415
# Fist detected
# X movement: 0.0009796202182769664
# Fist detected
# X movement: 0.0008691966533661
# Fist detected
# X movement: -0.00020069479942319557
# Fist detected
# X movement: -0.015297657251358066
# Fist moved left
# Volume Down triggered
# Fist detected
# X movement: -0.01694179773330684
# Fist moved left
# Open palm detected: Play/Pause triggered
# Thumb down detected: Rewind 5 secs
# Thumb down detected: Rewind 5 secs
# Fist detected
# Fist detected
# X movement: 0.011789143085479736
# Fist moved right
# Volume Up triggered
# Fist detected
# X movement: 0.006270128488540638
# Fist moved right
# Index finger up detected: Fast forward 5 secs
# Fist detected
# Fist detected
# X movement: -0.00034845471382138893
# Fist detected
# X movement: -0.0009266912937164751
# Fist detected
# X movement: -0.003445017337799061
# Fist detected
# X movement: -0.007226490974426236
# Fist moved left
# Volume Down triggered
# Fist detected
# X movement: -0.013528305292129561
# Fist moved left
# Open palm detected: Play/Pause triggered
# Thumb down detected: Rewind 5 secs
# Thumb down detected: Rewind 5 secs
# Quitting program

# %% [markdown]
# Capture Video and Detect Gestures

# %%
while cap.isOpened():
    start_time = time.time()

    success, frame = cap.read()
    if not success:
        print("Failed to capture frame")
        break
    
    # Convert the image to RGB
    image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    image.flags.writeable = False
    
    # Process the image and detect hands
    results = hands.process(image)
    image.flags.writeable = True
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    
    if results.multi_hand_landmarks:
        for hand_landmarks in results.multi_hand_landmarks:
            # Convert landmarks to numpy array for smoothing
            landmarks_array = np.array([(lm.x, lm.y, lm.z) for lm in hand_landmarks.landmark])
            
            # Smooth the landmarks
            smoothed_landmarks = smooth_landmarks(landmarks_array)
            
            # Check if the hand is open palm
            if is_open_palm_landmarks(smoothed_landmarks):
                if not is_open_palm and (time.time() - last_play_pause_time) > play_pause_delay:
                    print("Open palm detected: Play/Pause triggered")
                    pyautogui.press('space')
                    last_play_pause_time = time.time()
                    is_open_palm = True
                is_fist = False  # Reset fist status
            else:
                is_open_palm = False
            
            # Check if the hand is in a fist
            if is_fist_landmarks(smoothed_landmarks):
                print("Fist detected")
                current_position = smoothed_landmarks[9]  # Use landmark 9 as reference for fist position
                if is_fist and previous_fist_position is not None:
                    direction = get_fist_direction(current_position, previous_fist_position)
                    if direction == "left" and (time.time() - last_volume_change_time) > volume_change_delay:
                        print("Volume Down triggered")
                        pyautogui.press('volumedown')
                        last_volume_change_time = time.time()
                    elif direction == "right" and (time.time() - last_volume_change_time) > volume_change_delay:
                        print("Volume Up triggered")
                        pyautogui.press('volumeup')
                        last_volume_change_time = time.time()
                is_fist = True
                previous_fist_position = current_position  # Update the previous fist position
            else:
                is_fist = False

            # Check for thumbs up
            if is_thumbs_up_landmarks(smoothed_landmarks) and (time.time() - last_gesture_time) > gesture_delay:
                print("Thumbs up detected: Fast forward 5 secs")
                pyautogui.press('right')
                last_gesture_time = time.time()

            # Check for thumbs down
            if is_thumbs_down_landmarks(smoothed_landmarks) and (time.time() - last_gesture_time) > gesture_delay:
                print("Thumbs down detected: Rewind 5 secs")
                pyautogui.press('left')
                last_gesture_time = time.time()

            # Draw hand landmarks
            mp_draw.draw_landmarks(image, hand_landmarks, mp_hands.HAND_CONNECTIONS)
    
    # Display the video feed
    cv2.imshow('Hand Gesture Control', image)
    
    # Break loop with 'q' key
    if cv2.waitKey(1) & 0xFF == ord('q'):
        print("Quitting program")
        break

    # Frame rate control
    end_time = time.time()
    elapsed_time = end_time - start_time
    if elapsed_time < frame_duration:
        time.sleep(frame_duration - elapsed_time)

cap.release()
cv2.destroyAllWindows()
# Out:
# Open palm detected: Play/Pause triggered
# Thumbs down detected: Rewind 5 secs
# Thumbs down detected: Rewind 5 secs
# Thumbs up detected: Fast forward 5 secs
# Thumbs up detected: Fast forward 5 secs
# Open palm detected: Play/Pause triggered
# Thumbs up detected: Fast forward 5 secs
# Thumbs up detected: Fast forward 5 secs
# Thumbs up detected: Fast forward 5 secs
# Thumbs up detected: Fast forward 5 secs
# Thumbs up detected: Fast forward 5 secs
# Thumbs up detected: Fast forward 5 secs
# Thumbs up detected: Fast forward 5 secs
# Thumbs down detected: Rewind 5 secs
# Thumbs down detected: Rewind 5 secs
# Thumbs down detected: Rewind 5 secs
# Thumbs down detected: Rewind 5 secs
# Thumbs up detected: Fast forward 5 secs
# Thumbs up detected: Fast forward 5 secs
# Thumbs up detected: Fast forward 5 secs
# Thumbs down detected: Rewind 5 secs
# Thumbs down detected: Rewind 5 secs
# Thumbs down detected: Rewind 5 secs
# Fist detected
# Fist detected
# X movement: 0.001312774419784557
# Fist detected
# X movement: 0.001286184787750222
# Fist detected
# X movement: 0.002184492349624645
# Fist detected
# X movement: 0.002025568485260032
# Fist detected
# X movement: -0.0007638394832611417
# Fist detected
# X movement: -0.0001999080181121493
# Fist detected
# X movement: -0.00013424158096314587
# Fist detected
# X movement: -0.000885695219039917
# Fist detected
# X movement: -0.0004363238811492809
# Fist detected
# X movement: -4.30285930633767e-05
# Fist detected
# X movement: -0.0002574801445007213
# Fist detected
# X movement: 0.00012050867080687366
# Fist detected
# X movement: 6.351470947268956e-05
# Fist detected
# X movement: -3.45289707184282e-05
# Fist detected
# X movement: -1.6927719116210938e-05
# Fist detected
# X movement: -2.8347969055153577e-05
# Fist detected
# X movement: -0.00034936070442198597
# Fist detected
# X movement: -0.00010761618614196777
# Fist detected
# X movement: 5.4401159286510126e-05
# Fist detected
# X movement: 4.993081092830032e-05
# Fist detected
# X movement: 0.00020905733108522728
# Fist detected
# X movement: 0.000202178955078125
# Fist detected
# X movement: 0.0001608133316040039
# Fist detected
# X movement: -0.00027291178703309216
# Fist detected
# X movement: -0.00024678707122799404
# Fist detected
# X movement: -0.00033116936683658116
# Fist detected
# X movement: -9.505748748778187e-05
# Fist detected
# X movement: -0.00012436509132385254
# Fist detected
# X movement: 0.0001476764678954856
# Fist detected
# X movement: 0.00011619925498962402
# Fist detected
# X movement: 0.00033519268035892
# Fist detected
# X movement: 6.494522094724342e-05
# Fist detected
# X movement: 0.0008429229259491189
# Fist detected
# X movement: 0.0006042838096618763
# Fist detected
# X movement: 0.0004151284694671187
# Fist detected
# X movement: 0.0005383372306824175
# Fist detected
# X movement: 0.0006980359554290549
# Fist detected
# X movement: 1.3071298599232062e-05
# Fist detected
# X movement: 0.00041781067848206677
# Fist detected
# X movement: 0.0005110442638397439
# Fist detected
# X movement: -7.778406143188477e-05
# Fist detected
# X movement: -0.00019366145133975499
# Fist detected
# X movement: -0.0002637028694152943
# Open palm detected: Play/Pause triggered
# Thumbs down detected: Rewind 5 secs
# Thumbs down detected: Rewind 5 secs
# Thumbs down detected: Rewind 5 secs
# Thumbs up detected: Fast forward 5 secs
# Open palm detected: Play/Pause triggered
# Thumbs up detected: Fast forward 5 secs
# Thumbs down detected: Rewind 5 secs
# Thumbs down detected: Rewind 5 secs
# Thumbs down detected: Rewind 5 secs
# Thumbs up detected: Fast forward 5 secs
# Thumbs up detected: Fast forward 5 secs
# Thumbs up detected: Fast forward 5 secs
# Thumbs down detected: Rewind 5 secs
# Thumbs down detected: Rewind 5 secs
# Thumbs down detected: Rewind 5 secs
# Thumbs up detected: Fast forward 5 secs
# Thumbs up detected: Fast forward 5 secs
# Thumbs down detected: Rewind 5 secs
# Thumbs up detected: Fast forward 5 secs
# Thumbs up detected: Fast forward 5 secs
# Thumbs up detected: Fast forward 5 secs
# Thumbs up detected: Fast forward 5 secs
# Thumbs up detected: Fast forward 5 secs
# Thumbs up detected: Fast forward 5 secs
# Thumbs up detected: Fast forward 5 secs
# Thumbs up detected: Fast forward 5 secs
# Thumbs down detected: Rewind 5 secs
# Thumbs down detected: Rewind 5 secs
# Thumbs up detected: Fast forward 5 secs
# Thumbs up detected: Fast forward 5 secs
# Thumbs up detected: Fast forward 5 secs
# Thumbs up detected: Fast forward 5 secs
# Fist detected
# Fist detected
# X movement: 0.010102412104606606
# Fist moved right
# Volume Up triggered
# Fist detected
# X movement: 0.0053810387849807795
# Fist moved right
# Fist detected
# X movement: 0.004884013533592219
# Fist detected
# X movement: 0.0031699270009994673
# Fist detected
# X movement: -0.0025944679975509755
# Fist detected
# X movement: -0.0035730093717575018
# Fist detected
# X movement: -0.0023618429899215643
# Fist detected
# X movement: -0.0016792267560958862
# Thumbs up detected: Fast forward 5 secs
# Fist detected
# X movement: -0.0004048198461532593
# Fist detected
# X movement: 0.00015577375888822798
# Fist detected
# X movement: 0.0010543048381805586
# Fist detected
# X movement: 0.00154874026775359
# Fist detected
# X movement: 0.0013775825500488281
# Fist detected
# X movement: 0.0007424801588058472
# Fist detected
# X movement: 0.0005789577960968184
# Fist detected
# X movement: 0.0008494675159454179
# Fist detected
# X movement: 0.0005006849765777643
# Fist detected
# X movement: 0.000240159034729015
# Fist detected
# X movement: 0.0002492606639862005
# Fist detected
# X movement: 0.0009432882070541382
# Fist detected
# X movement: 7.66605138778631e-05
# Fist detected
# X movement: -0.00021591484546662487
# Fist detected
# X movement: -0.00015777647495268665
# Fist detected
# X movement: 0.00043952763080595814
# Fist detected
# X movement: -0.0008592009544372559
# Fist detected
# X movement: -0.000275871157646157
# Fist detected
# X movement: 0.00010887682437896173
# Fist detected
# X movement: -0.0001553863286972157
# Thumbs up detected: Fast forward 5 secs
# Fist detected
# X movement: -0.0006244093179702814
# Fist detected
# X movement: -5.943179130551979e-05
# Fist detected
# X movement: -0.002292072772979742
# Fist detected
# X movement: -0.003239232301712053
# Fist detected
# X movement: -0.004616451263427718
# Fist detected
# X movement: -0.003661382198333757
# Fist detected
# X movement: -0.004085251688957209
# Fist detected
# X movement: -0.004932877421379073
# Fist detected
# X movement: -0.006315955519676231
# Fist moved left
# Volume Down triggered
# Fist detected
# X movement: -0.005593550205230696
# Fist moved left
# Fist detected
# X movement: -0.005510511994361894
# Fist moved left
# Fist detected
# X movement: -0.005378457903861988
# Fist moved left
# Fist detected
# X movement: -0.004761844873428345
# Fist detected
# X movement: -0.004076176881790156
# Fist detected
# X movement: -0.002354741096496582
# Fist detected
# X movement: -0.0030573487281799483
# Fist detected
# X movement: -0.0031634807586669866
# Fist detected
# X movement: -0.00030259788036346436
# Fist detected
# X movement: 0.0011560142040252797
# Fist detected
# X movement: 0.0002873539924621582
# Thumbs up detected: Fast forward 5 secs
# Fist detected
# X movement: -0.00047310590744018
# Fist detected
# X movement: -0.00039280951023101807
# Fist detected
# X movement: -0.0009718626737594827
# Fist detected
# X movement: -0.0006887048482894786
# Fist detected
# X movement: -0.0007141262292861827
# Fist detected
# X movement: 9.480416774748646e-05
# Fist detected
# X movement: 0.00028813779354094904
# Fist detected
# X movement: 0.0008289635181427113
# Fist detected
# X movement: 0.000532796978950506
# Fist detected
# X movement: 0.0002841264009475486
# Fist detected
# X movement: 0.00019963383674623247
# Fist detected
# X movement: 0.0003537416458129772
# Fist detected
# X movement: 0.0006922870874404852
# Fist detected
# X movement: 0.002452310919761669
# Fist detected
# X movement: 0.0022738963365554754
# Fist detected
# X movement: 0.002763515710830694
# Fist detected
# X movement: 0.003863915801048279
# Fist detected
# X movement: 0.004561343789100641
# Fist detected
# X movement: 0.002697411179542558
# Fist detected
# X movement: 0.003575673699378945
# Thumbs up detected: Fast forward 5 secs
# Fist detected
# X movement: 0.00471424460411074
# Fist detected
# X movement: 0.004774516820907571
# Fist detected
# X movement: 0.0035459041595459206
# Fist detected
# X movement: 0.0036653250455856157
# Fist detected
# X movement: 0.0032776236534118597
# Fist detected
# X movement: 0.0022237628698349166
# Fist detected
# X movement: 0.0010793685913085826
# Fist detected
# X movement: 0.001191756129264837
# Fist detected
# X movement: 0.00146542489528656
# Fist detected
# X movement: 0.001920434832572926
# Fist detected
# X movement: 0.0011407405138015858
# Fist detected
# X movement: 0.0008981645107269398
# Fist detected
# X movement: 0.0013977587223052979
# Fist detected
# X movement: 0.0009753435850143322
# Fist detected
# X movement: 0.0007215052843093928
# Fist detected
# X movement: 0.0016780734062194769
# Fist detected
# X movement: 0.0013837307691574041
# Fist detected
# X movement: 0.0021141141653061024
# Fist detected
# X movement: 0.00214565992355345
# Fist detected
# X movement: 0.002086284756660478
# Fist detected
# X movement: 0.002085664868354792
# Fist detected
# X movement: 0.003046336770057667
# Thumbs up detected: Fast forward 5 secs
# Fist detected
# X movement: 0.0029000401496887263
# Fist detected
# X movement: 0.0030828118324279785
# Fist detected
# X movement: 0.003004643321037309
# Fist detected
# X movement: 0.0028849273920059093
# Fist detected
# X movement: 0.0020879238843917736
# Fist detected
# X movement: 0.00057894587516788
# Fist detected
# X movement: 0.0029572755098342673
# Fist detected
# X movement: 0.0037720263004302756
# Fist detected
# X movement: 0.0026260495185852495
# Fist detected
# X movement: 0.003049010038375821
# Fist detected
# X movement: 0.003278934955596946
# Fist detected
# X movement: 0.0014052212238311879
# Fist detected
# X movement: 0.0003435373306274192
# Fist detected
# X movement: 0.0011065781116485485
# Fist detected
# X movement: -4.3511390686035156e-05
# Fist detected
# X movement: -0.0005021393299102783
# Fist detected
# X movement: -0.0012211084365844616
# Fist detected
# X movement: -0.0009971559047698975
# Fist detected
# X movement: -0.001015174388885487
# Fist detected
# X movement: -0.0006835639476776012
# Fist detected
# X movement: -6.289482116700329e-05
# Fist detected
# X movement: 0.00029990673065183326
# Thumbs up detected: Fast forward 5 secs
# Fist detected
# X movement: -0.00040792226791380726
# Fist detected
# X movement: -0.00021495819091799095
# Fist detected
# X movement: 0.00012697577476505906
# Fist detected
# X movement: -0.00024628639221191406
# Fist detected
# X movement: 2.872943878173828e-05
# Fist detected
# X movement: 0.0008208394050597811
# Fist detected
# X movement: 0.00015979409217836693
# Fist detected
# X movement: 0.000531780719757069
# Fist detected
# X movement: -6.31868839263694e-05
# Fist detected
# X movement: -8.079409599304199e-05
# Fist detected
# X movement: -0.0007079720497131792
# Fist detected
# X movement: -8.271932601927601e-05
# Fist detected
# X movement: -0.0006638705730437899
# Fist detected
# X movement: 0.00025662779808044434
# Fist detected
# X movement: 0.00044531822204585403
# Fist detected
# X movement: 0.0011826336383820024
# Fist detected
# X movement: -0.0005399346351623868
# Fist detected
# X movement: -0.0005145609378814364
# Fist detected
# X movement: -0.0009617805480957031
# Fist detected
# X movement: -0.0014640152454376554
# Fist detected
# X movement: -0.0018549323081969993
# Thumbs up detected: Fast forward 5 secs
# Fist detected
# X movement: -0.00048436522483824573
# Fist detected
# X movement: -0.0001514434814453569
# Fist detected
# X movement: -0.00024907588958739124
# Fist detected
# X movement: -0.00034580230712888405
# Fist detected
# X movement: 0.002400809526443448
# Fist detected
# X movement: 0.0024617552757263406
# Fist detected
# X movement: 0.0027655065059661865
# Fist detected
# X movement: 0.002891576290130593
# Fist detected
# X movement: 0.004352998733520519
# Fist detected
# X movement: 0.0014901280403137318
# Fist detected
# X movement: 0.0008917212486266868
# Fist detected
# X movement: 0.0008391022682190385
# Fist detected
# X movement: 0.0006103038787841353
# Fist detected
# X movement: -0.0007927477359771506
# Fist detected
# X movement: -0.0005760788917541504
# Fist detected
# X movement: -4.821419715883568e-05
# Fist detected
# X movement: -0.00024229884147641823
# Fist detected
# X movement: -0.00018399357795717552
# Fist detected
# X movement: 0.0002685964107513872
# Fist detected
# X movement: 0.00014995336532591663
# Fist detected
# X movement: 0.0004323840141296498
# Fist detected
# X movement: 0.00033069849014277786
# Fist detected
# X movement: 0.0004968225955963579
# Thumbs up detected: Fast forward 5 secs
# Fist detected
# X movement: -6.166696548465245e-05
# Fist detected
# X movement: -0.00019965767860413708
# Fist detected
# X movement: -0.0006936550140380637
# Fist detected
# X movement: -0.00045491456985474743
# Fist detected
# X movement: -0.0017031371593475009
# Fist detected
# X movement: -0.004835307598114014
# Fist detected
# X movement: -0.0043712377548217884
# Fist detected
# X movement: -0.004111999273300193
# Fist detected
# X movement: -0.006477245688438382
# Fist moved left
# Volume Down triggered
# Fist detected
# X movement: -0.006396323442459134
# Fist moved left
# Fist detected
# X movement: -0.00485420525074004
# Fist detected
# X movement: -0.004709091782569896
# Fist detected
# X movement: -0.004746571183204651
# Fist detected
# X movement: -0.003502598404884344
# Fist detected
# X movement: -0.0023700594902038574
# Fist detected
# X movement: -0.000724440813064553
# Fist detected
# X movement: -0.0008984357118606567
# Fist detected
# X movement: -0.0016022443771362416
# Fist detected
# X movement: -0.001093509793281544
# Fist detected
# X movement: -0.0014956146478652954
# Thumbs up detected: Fast forward 5 secs
# Fist detected
# X movement: -0.0014054536819458063
# Fist detected
# X movement: -0.0021954149007797352
# Fist detected
# X movement: -0.0014052033424377386
# Fist detected
# X movement: -0.001008513569831837
# Fist detected
# X movement: -0.0005616903305053766
# Fist detected
# X movement: -0.0002860248088836781
# Fist detected
# X movement: 9.612441062928356e-05
# Fist detected
# X movement: -8.081495761871893e-05
# Fist detected
# X movement: -0.00013286173343657337
# Fist detected
# X movement: 0.0008611470460891668
# Fist detected
# X movement: 0.0006998300552367998
# Fist detected
# X movement: 0.0004296153783798218
# Fist detected
# X movement: 0.0013195484876632746
# Fist detected
# X movement: 0.00292960405349732
# Fist detected
# X movement: 0.0017405301332473755
# Fist detected
# X movement: 0.0019487261772155873
# Fist detected
# X movement: 0.002310398221015919
# Fist detected
# X movement: 0.00325125753879546
# Fist detected
# X movement: 0.0017866015434265248
# Fist detected
# X movement: 0.002225276827812206
# Fist detected
# X movement: 0.00445717275142668
# Fist detected
# X movement: 0.0068911880254745594
# Fist moved right
# Volume Up triggered
# Thumbs up detected: Fast forward 5 secs
# Fist detected
# X movement: 0.006690758466720598
# Fist moved right
# Fist detected
# X movement: 0.00860824882984157
# Fist moved right
# Fist detected
# X movement: 0.008141857385635387
# Fist moved right
# Volume Up triggered
# Fist detected
# X movement: 0.007745265960693359
# Fist moved right
# Fist detected
# X movement: 0.00784146785736084
# Fist moved right
# Fist detected
# X movement: 0.006339037418365501
# Fist moved right
# Fist detected
# X movement: 0.004221731424331632
# Fist detected
# X movement: 0.00798029899597169
# Fist moved right
# Fist detected
# X movement: 0.008518254756927524
# Fist moved right
# Volume Up triggered
# Fist detected
# X movement: 0.010539835691452004
# Fist moved right
# Fist detected
# X movement: 0.010265004634857189
# Fist moved right
# Fist detected
# X movement: 0.010495734214782726
# Fist moved right
# Fist detected
# X movement: 0.011303746700286832
# Fist moved right
# Fist detected
# X movement: 0.012040495872497559
# Fist moved right
# Volume Up triggered
# Fist detected
# X movement: 0.013426107168197643
# Fist moved right
# Fist detected
# X movement: 0.013137018680572488
# Fist moved right
# Thumbs up detected: Fast forward 5 secs
# Fist detected
# X movement: 0.015551203489303611
# Fist moved right
# Fist detected
# X movement: 0.01580490469932555
# Fist moved right
# Volume Up triggered
# Fist detected
# X movement: 0.015771865844726562
# Fist moved right
# Fist detected
# X movement: 0.011159628629684448
# Fist moved right
# Fist detected
# X movement: 0.01114632487297057
# Fist moved right
# Fist detected
# X movement: 0.011876171827316317
# Fist moved right
# Fist detected
# X movement: 0.013533473014831543
# Fist moved right
# Volume Up triggered
# Fist detected
# X movement: 0.006560426950454723
# Fist moved right
# Fist detected
# X movement: 0.008375668525695823
# Fist moved right
# Fist detected
# X movement: 0.01027786135673514
# Fist moved right
# Fist detected
# X movement: 0.00535632967948918
# Fist moved right
# Fist detected
# X movement: 0.00031719207763669655
# Fist detected
# X movement: 0.0037350773811341
# Fist detected
# X movement: 0.0010736942291259544
# Fist detected
# X movement: -0.0012829422950745295
# Fist detected
# X movement: -0.0003772020339964932
# Thumbs down detected: Rewind 5 secs
# Fist detected
# X movement: -0.0017765641212463823
# Fist detected
# X movement: -0.0006745696067810281
# Fist detected
# X movement: -0.0011672139167785422
# Fist detected
# X movement: -0.0032461762428284135
# Fist detected
# X movement: -0.004869389533996515
# Fist detected
# X movement: -0.0038681268692016824
# Fist detected
# X movement: -0.004865008592605635
# Fist detected
# X movement: -0.003452682495117154
# Fist detected
# X movement: -0.0041389644145965465
# Fist detected
# X movement: -0.001126927137374889
# Fist detected
# X movement: -0.0012087285518646018
# Fist detected
# X movement: -0.0023438811302184948
# Fist detected
# X movement: -0.005035853385925326
# Fist moved left
# Volume Down triggered
# Fist detected
# X movement: -0.0019563555717468373
# Fist detected
# X movement: -0.004223150014877275
# Fist detected
# X movement: -0.006300944089889571
# Fist moved left
# Fist detected
# X movement: -0.0044139444828033
# Fist detected
# X movement: -0.0024112880229950062
# Fist detected
# X movement: -0.0026516675949097013
# Fist detected
# X movement: -0.002384918928146351
# Fist detected
# X movement: -0.004076927900314331
# Fist detected
# X movement: -0.0042906105518341064
# Fist detected
# X movement: -0.005403178930282582
# Fist moved left
# Volume Down triggered
# Fist detected
# X movement: -0.004797357320785511
# Thumbs down detected: Rewind 5 secs
# Fist detected
# X movement: -0.005543982982635531
# Fist moved left
# Fist detected
# X movement: -0.005131500959396351
# Fist moved left
# Fist detected
# X movement: -0.006124418973922741
# Fist moved left
# Volume Down triggered
# Fist detected
# X movement: -0.007170236110687234
# Fist moved left
# Fist detected
# X movement: -0.00780714154243467
# Fist moved left
# Fist detected
# X movement: -0.00505374670028691
# Fist moved left
# Fist detected
# X movement: -0.0025852262973785067
# Fist detected
# X movement: -0.0017871558666229248
# Fist detected
# X movement: -0.0007888734340668058
# Fist detected
# X movement: -0.0005262494087219238
# Fist detected
# X movement: -0.0017118096351623202
# Fist detected
# X movement: -0.00158563852310184
# Fist detected
# X movement: -0.0021596908569335715
# Fist detected
# X movement: -0.001732558012008667
# Fist detected
# X movement: -0.0011183440685272328
# Fist detected
# X movement: -0.00045729875564576306
# Fist detected
# X movement: -0.0006583571434020663
# Fist detected
# X movement: -0.0004257380962371937
# Fist detected
# X movement: -0.002045661211013794
# Fist detected
# X movement: -0.0014679849147796742
# Fist detected
# X movement: -0.0025800883769989125
# Thumbs up detected: Fast forward 5 secs
# Fist detected
# X movement: -0.0037947833538055087
# Fist detected
# X movement: -0.003372925519943226
# Fist detected
# X movement: -0.0014431118965149148
# Fist detected
# X movement: -0.003517198562622059
# Fist detected
# X movement: -0.004138326644897494
# Fist detected
# X movement: -0.0025263786315917747
# Fist detected
# X movement: -0.002688974142074585
# Fist detected
# X movement: -0.003850221633911133
# Fist detected
# X movement: -0.0029232680797576793
# Fist detected
# X movement: -0.001224595308303822
# Fist detected
# X movement: -0.0014151990413666105
# Fist detected
# X movement: -0.0018708169460296409
# Fist detected
# X movement: -0.0011237204074859841
# Fist detected
# X movement: -0.0005057454109191895
# Fist detected
# X movement: -0.0004080533981323242
# Fist detected
# X movement: -0.001058173179626476
# Fist detected
# X movement: -0.0007081329822540283
# Fist detected
# X movement: -0.00042716264724729225
# Fist detected
# X movement: -0.0004539310932159535
# Fist detected
# X movement: -4.7820806503284796e-05
# Fist detected
# X movement: 0.00046526193618773304
# Fist detected
# X movement: 0.0003710150718689298
# Thumbs up detected: Fast forward 5 secs
# Fist detected
# X movement: 0.0002663612365722545
# Fist detected
# X movement: 0.0004997313022613303
# Fist detected
# X movement: -0.0005134105682372825
# Fist detected
# X movement: -0.00017015337944031872
# Fist detected
# X movement: -0.0001757502555846946
# Fist detected
# X movement: -0.0006428718566894864
# Open palm detected: Play/Pause triggered
# Fist detected
# Fist detected
# X movement: -0.0051111221313476785
# Fist moved left
# Volume Down triggered
# Fist detected
# X movement: -0.001996690034866355
# Thumbs up detected: Fast forward 5 secs
# Fist detected
# X movement: 0.0011178672313690297
# Fist detected
# X movement: 4.710555076598011e-05
# Fist detected
# X movement: 0.00029060840606692784
# Fist detected
# X movement: 0.004233086109161344
# Fist detected
# X movement: 0.0030241429805755726
# Fist detected
# X movement: 0.003329974412918102
# Fist detected
# X movement: 0.003745347261428833
# Fist detected
# X movement: 0.004842185974121116
# Thumbs down detected: Rewind 5 secs
# Open palm detected: Play/Pause triggered
# Fist detected
# Fist detected
# X movement: 0.006474459171295188
# Fist moved right
# Volume Up triggered
# Thumbs up detected: Fast forward 5 secs
# Fist detected
# X movement: 0.005548334121704079
# Fist moved right
# Fist detected
# X movement: 0.006346499919891335
# Fist moved right
# Volume Up triggered
# Fist detected
# X movement: 0.001223760843277022
# Open palm detected: Play/Pause triggered
# Thumbs down detected: Rewind 5 secs
# Thumbs down detected: Rewind 5 secs
# Thumbs down detected: Rewind 5 secs
# Thumbs down detected: Rewind 5 secs
# Thumbs up detected: Fast forward 5 secs
# Thumbs up detected: Fast forward 5 secs
# Thumbs up detected: Fast forward 5 secs
# Thumbs up detected: Fast forward 5 secs
# Open palm detected: Play/Pause triggered
# Thumbs down detected: Rewind 5 secs
# Thumbs down detected: Rewind 5 secs
# Thumbs down detected: Rewind 5 secs
# Thumbs up detected: Fast forward 5 secs
# Thumbs up detected: Fast forward 5 secs
# Thumbs up detected: Fast forward 5 secs
# Thumbs down detected: Rewind 5 secs
# Open palm detected: Play/Pause triggered
# Thumbs down detected: Rewind 5 secs
# Thumbs down detected: Rewind 5 secs
# Quitting program
