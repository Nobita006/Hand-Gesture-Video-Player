# %%
pip install opencv-python mediapipe pyautogui
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: opencv-python in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (4.10.0.84)
# Requirement already satisfied: mediapipe in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (0.10.14)
# Requirement already satisfied: pyautogui in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (0.9.54)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from opencv-python) (2.0.1)
# Requirement already satisfied: absl-py in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from mediapipe) (2.1.0)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from mediapipe) (24.2.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from mediapipe) (24.3.25)
# Requirement already satisfied: jax in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from mediapipe) (0.4.31)
# Requirement already satisfied: jaxlib in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from mediapipe) (0.4.31)
# Requirement already satisfied: matplotlib in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from mediapipe) (3.9.2)
# Requirement already satisfied: opencv-contrib-python in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from mediapipe) (4.10.0.84)
# Requirement already satisfied: protobuf<5,>=4.25.3 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from mediapipe) (4.25.4)
# Requirement already satisfied: sounddevice>=0.4.4 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from mediapipe) (0.5.0)
# Requirement already satisfied: pymsgbox in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from pyautogui) (1.0.9)
# Requirement already satisfied: pytweening>=1.0.4 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from pyautogui) (1.2.0)
# Requirement already satisfied: pyscreeze>=0.1.21 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from pyautogui) (0.1.30)
# Requirement already satisfied: pygetwindow>=0.0.5 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from pyautogui) (0.0.9)
# Requirement already satisfied: mouseinfo in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from pyautogui) (0.1.3)
# Requirement already satisfied: pyrect in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from pygetwindow>=0.0.5->pyautogui) (0.2.0)
# Requirement already satisfied: CFFI>=1.0 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from sounddevice>=0.4.4->mediapipe) (1.17.0)
# Requirement already satisfied: ml-dtypes>=0.2.0 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from jax->mediapipe) (0.4.0)
# Requirement already satisfied: opt-einsum in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from jax->mediapipe) (3.3.0)
# Requirement already satisfied: scipy>=1.10 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from jax->mediapipe) (1.14.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mediapipe) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mediapipe) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mediapipe) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\sayan\appdata\roaming\python\python312\site-packages (from matplotlib->mediapipe) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mediapipe) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mediapipe) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sayan\appdata\roaming\python\python312\site-packages (from matplotlib->mediapipe) (2.9.0.post0)
# Requirement already satisfied: pyperclip in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from mouseinfo->pyautogui) (1.9.0)
# Requirement already satisfied: pycparser in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.22)
# Requirement already satisfied: six>=1.5 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.16.0)
# [notice] A new release of pip is available: 24.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Import Libraries and Set Up Hand Detection

# %%
import cv2
import mediapipe as mp
import pyautogui
import time
import numpy as np
from collections import deque

# Initialize Mediapipe hand detection with higher confidence thresholds
mp_hands = mp.solutions.hands
hands = mp_hands.Hands(max_num_hands=1, min_detection_confidence=0.8, min_tracking_confidence=0.8)
mp_draw = mp.solutions.drawing_utils

# Variables for delay management
last_play_pause_time = time.time()
last_volume_change_time = time.time()
last_gesture_time = time.time()

# Thresholds
play_pause_delay = 1  # 1 second delay for play/pause
volume_change_delay = 0.2  # 1/5 second delay for volume change
gesture_delay = 1  # 1 second delay for gestures
movement_threshold = 0.005  # adjust threshold for detecting meaningful fist movements

# Gesture States
is_open_palm = False
is_fist = False
previous_fist_position = None
debug_text = ""  # Text to display on the video feed

# Frame rate control
target_fps = 24
frame_duration = 1.0 / target_fps

# Smoothing settings
smoothing_window_size = 5
landmark_queue = deque(maxlen=smoothing_window_size)

# Capture video from webcam
cap = cv2.VideoCapture(0)

def is_open_palm_landmarks(landmarks):
    return landmarks[8][1] < landmarks[6][1] and \
           landmarks[12][1] < landmarks[10][1] and \
           landmarks[16][1] < landmarks[14][1] and \
           landmarks[20][1] < landmarks[18][1]

def is_fist_landmarks(landmarks):
    return landmarks[8][1] > landmarks[6][1] and \
           landmarks[12][1] > landmarks[10][1] and \
           landmarks[16][1] > landmarks[14][1] and \
           landmarks[20][1] > landmarks[18][1]

def is_index_finger_pointing_up(landmarks):
    return landmarks[8][1] < landmarks[6][1] and \
           landmarks[12][1] > landmarks[10][1] and \
           landmarks[16][1] > landmarks[14][1] and \
           landmarks[20][1] > landmarks[18][1]

def is_thumb_down(landmarks):
    return landmarks[4][1] > landmarks[3][1] and \
           landmarks[8][1] < landmarks[6][1] and \
           landmarks[12][1] < landmarks[10][1] and \
           landmarks[16][1] < landmarks[14][1] and \
           landmarks[20][1] < landmarks[18][1]

def get_fist_direction(current_position, previous_position):
    if current_position is not None and previous_position is not None:
        x_movement = current_position[0] - previous_position[0]
        return x_movement
    return None

def smooth_landmarks(landmarks):
    landmark_queue.append(landmarks)
    avg_landmarks = np.mean(landmark_queue, axis=0)
    return avg_landmarks

while cap.isOpened():
    start_time = time.time()

    success, frame = cap.read()
    if not success:
        print("Failed to capture frame")
        break
    
    # Convert the image to RGB
    image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    image.flags.writeable = False
    
    # Process the image and detect hands
    results = hands.process(image)
    image.flags.writeable = True
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    
    if results.multi_hand_landmarks:
        for hand_landmarks in results.multi_hand_landmarks:
            # Convert landmarks to numpy array for smoothing
            landmarks_array = np.array([(lm.x, lm.y, lm.z) for lm in hand_landmarks.landmark])
            
            # Smooth the landmarks
            smoothed_landmarks = smooth_landmarks(landmarks_array)
            
            # Check if the hand is open palm
            if is_open_palm_landmarks(smoothed_landmarks):
                if not is_open_palm and (time.time() - last_play_pause_time) > play_pause_delay:
                    debug_text = "Open palm detected: Play/Pause triggered"
                    print(debug_text)
                    pyautogui.press('space')
                    last_play_pause_time = time.time()
                    is_open_palm = True
                is_fist = False  # Reset fist status
            else:
                is_open_palm = False
            
            # Check if the hand is in a fist
            if is_fist_landmarks(smoothed_landmarks):
                debug_text = "Fist detected"
                print(debug_text)
                current_position = smoothed_landmarks[9]  # Use landmark 9 as reference for fist position
                if is_fist and previous_fist_position is not None:
                    x_movement = get_fist_direction(current_position, previous_fist_position)
                    if x_movement:
                        debug_text = f"X movement: {x_movement}"
                        print(debug_text)
                        if x_movement < -movement_threshold and (time.time() - last_volume_change_time) > volume_change_delay:
                            debug_text = "Volume Down triggered"
                            print(debug_text)
                            pyautogui.press('volumedown')
                            last_volume_change_time = time.time()
                        elif x_movement > movement_threshold and (time.time() - last_volume_change_time) > volume_change_delay:
                            debug_text = "Volume Up triggered"
                            print(debug_text)
                            pyautogui.press('volumeup')
                            last_volume_change_time = time.time()
                is_fist = True
                previous_fist_position = current_position  # Update the previous fist position
            else:
                is_fist = False

            # Check for index finger pointing up
            if is_index_finger_pointing_up(smoothed_landmarks) and (time.time() - last_gesture_time) > gesture_delay:
                debug_text = "Index finger up detected: Fast forward 5 secs"
                print(debug_text)
                pyautogui.press('right')
                last_gesture_time = time.time()

            # Check for thumb down
            if is_thumb_down(smoothed_landmarks) and (time.time() - last_gesture_time) > gesture_delay:
                debug_text = "Thumb down detected: Rewind 5 secs"
                print(debug_text)
                pyautogui.press('left')
                last_gesture_time = time.time()

            # Draw hand landmarks
            mp_draw.draw_landmarks(image, hand_landmarks, mp_hands.HAND_CONNECTIONS)

            # Display the debug text on the video feed
            cv2.putText(image, debug_text, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2, cv2.LINE_AA)
    
    # Display the video feed
    cv2.imshow('Hand Gesture Control', image)
    
    # Break loop with 'q' key
    if cv2.waitKey(1) & 0xFF == ord('q'):
        print("Quitting program")
        break

    # Frame rate control
    end_time = time.time()
    elapsed_time = end_time - start_time
    if elapsed_time < frame_duration:
        time.sleep(frame_duration - elapsed_time)

cap.release()
cv2.destroyAllWindows()
# Out:
# Open palm detected: Play/Pause triggered
# Index finger up detected: Fast forward 5 secs
# Open palm detected: Play/Pause triggered
# Fist detected
# Fist detected
# X movement: -0.0009413897991180087
# Fist detected
# X movement: -0.0005737662315368763
# Fist detected
# X movement: -2.567768096922718e-05
# Fist detected
# X movement: 0.0002780795097350741
# Open palm detected: Play/Pause triggered
# Fist detected
# Fist detected
# X movement: -0.002808868885040283
# Fist detected
# X movement: -0.0022542536258697288
# Fist detected
# X movement: -0.0012466788291931041
# Fist detected
# X movement: -0.0002993762493133656
# Fist detected
# X movement: -0.0004285275936126709
# Fist detected
# X movement: -0.000398099422454834
# Fist detected
# X movement: -0.00043759942054749645
# Fist detected
# X movement: -0.0003159463405609242
# Fist detected
# X movement: -1.5985965728770868e-05
# Fist detected
# X movement: -0.00039495229721064895
# Fist detected
# X movement: 9.664297103878505e-05
# Fist detected
# X movement: 0.0015637993812561146
# Fist detected
# X movement: 0.0019515395164489968
# Fist detected
# X movement: 0.004176443815231301
# Fist detected
# X movement: 0.005434530973434437
# Volume Up triggered
# Fist detected
# X movement: 0.014560365676879905
# Fist detected
# X movement: 0.013243049383163452
# Fist detected
# X movement: 0.0182164669036865
# Volume Up triggered
# Fist detected
# X movement: 0.022736430168151855
# Fist detected
# X movement: 0.027444469928741444
# Fist detected
# X movement: 0.017468953132629417
# Volume Up triggered
# Fist detected
# X movement: 0.024946594238281272
# Fist detected
# X movement: 0.02765474915504451
# Fist detected
# X movement: 0.021771228313446023
# Fist detected
# X movement: 0.019478750228881903
# Volume Up triggered
# Fist detected
# X movement: 0.021463716030120872
# Fist detected
# X movement: 0.01932139396667476
# Fist detected
# X movement: 0.01264125108718872
# Volume Up triggered
# Fist detected
# X movement: 0.016531312465667747
# Fist detected
# X movement: 0.013751387596130371
# Fist detected
# X movement: 0.016991281509399436
# Volume Up triggered
# Fist detected
# X movement: 0.012724912166595437
# Fist detected
# X movement: 0.011428010463714555
# Fist detected
# X movement: 0.006230747699737527
# Volume Up triggered
# Fist detected
# X movement: -0.001408028602600031
# Fist detected
# X movement: -0.009877955913543679
# Fist detected
# X movement: -0.012385237216949507
# Volume Down triggered
# Fist detected
# X movement: -0.01735998392105098
# Fist detected
# X movement: -0.021252548694610685
# Fist detected
# X movement: -0.015665090084075906
# Volume Down triggered
# Fist detected
# X movement: -0.014873051643371604
# Fist detected
# X movement: -0.019547235965728715
# Fist detected
# X movement: -0.015540027618408225
# Volume Down triggered
# Fist detected
# X movement: -0.020379471778869562
# Fist detected
# X movement: -0.020394825935363792
# Fist detected
# X movement: -0.02307393550872805
# Volume Down triggered
# Fist detected
# X movement: -0.024161976575851396
# Fist detected
# X movement: -0.024558764696121282
# Fist detected
# X movement: -0.0235962152481079
# Fist detected
# X movement: -0.02332085371017456
# Volume Down triggered
# Fist detected
# X movement: -0.024993151426315308
# Fist detected
# X movement: -0.024069392681121793
# Fist detected
# X movement: -0.023519533872604415
# Volume Down triggered
# Fist detected
# X movement: -0.023183852434158325
# Fist detected
# X movement: -0.023020237684249878
# Fist detected
# X movement: -0.020742756128311113
# Volume Down triggered
# Fist detected
# X movement: -0.01895820498466494
# Fist detected
# X movement: -0.021696752309799172
# Fist detected
# X movement: -0.015360713005065946
# Volume Down triggered
# Fist detected
# X movement: -0.020423310995101918
# Fist detected
# X movement: -0.015595623850822443
# Fist detected
# X movement: -0.013786622881889365
# Volume Down triggered
# Fist detected
# X movement: -0.012230476737022378
# Fist detected
# X movement: -0.011536589264869695
# Fist detected
# X movement: -0.0055489122867584395
# Volume Down triggered
# Fist detected
# X movement: -0.005151709914207436
# Fist detected
# X movement: -0.002576512098312389
# Fist detected
# X movement: -0.00040948688983916126
# Fist detected
# X movement: 0.0026698768138885276
# Fist detected
# X movement: 0.003342679142951971
# Fist detected
# X movement: 0.00483996868133546
# Fist detected
# X movement: 0.0046065449714660645
# Fist detected
# X movement: 0.0064957052469253596
# Volume Up triggered
# Fist detected
# X movement: 0.006622326374053938
# Fist detected
# X movement: 0.006703224778175365
# Fist detected
# X movement: 0.00877437591552735
# Volume Up triggered
# Fist detected
# X movement: 0.011642175912857045
# Fist detected
# X movement: 0.012922462821006786
# Open palm detected: Play/Pause triggered
# Fist detected
# Fist detected
# X movement: 0.0024053871631622425
# Fist detected
# X movement: 0.0004347503185271884
# Fist detected
# X movement: 0.00048772096633914463
# Fist detected
# X movement: 0.00020690560340880237
# Open palm detected: Play/Pause triggered
# Index finger up detected: Fast forward 5 secs
# Index finger up detected: Fast forward 5 secs
# Index finger up detected: Fast forward 5 secs
# Index finger up detected: Fast forward 5 secs
# Open palm detected: Play/Pause triggered
# Thumb down detected: Rewind 5 secs
# Thumb down detected: Rewind 5 secs
# Thumb down detected: Rewind 5 secs
# Thumb down detected: Rewind 5 secs
# Fist detected
# Fist detected
# X movement: 0.0017360985279082919
# Open palm detected: Play/Pause triggered
# Index finger up detected: Fast forward 5 secs
# Index finger up detected: Fast forward 5 secs
# Index finger up detected: Fast forward 5 secs
# Index finger up detected: Fast forward 5 secs
# Index finger up detected: Fast forward 5 secs
# Index finger up detected: Fast forward 5 secs
# Index finger up detected: Fast forward 5 secs
# Open palm detected: Play/Pause triggered
# Index finger up detected: Fast forward 5 secs
# Open palm detected: Play/Pause triggered
# Open palm detected: Play/Pause triggered
# Fist detected
# Fist detected
# X movement: -0.003992575407028187
# Fist detected
# X movement: -0.0025401771068572776
# Fist detected
# X movement: -0.0012292861938476562
# Fist detected
# X movement: 0.0010405153036117387
# Fist detected
# X movement: 0.0001241296529770064
# Fist detected
# X movement: 0.0005899697542190441
# Fist detected
# X movement: 0.00036748349666596014
# Fist detected
# X movement: -3.6782026290899106e-05
# Fist detected
# X movement: -0.0004893392324447632
# Fist detected
# X movement: -4.8980116844177246e-05
# Fist detected
# X movement: -0.00020015239715576172
# Fist detected
# X movement: -0.0003624379634857289
# Fist detected
# X movement: 0.0003125309944153054
# Fist detected
# X movement: 0.0007228225469589067
# Fist detected
# X movement: 0.0016179203987121415
# Fist detected
# X movement: 0.004896059632301331
# Fist detected
# X movement: 0.005930575728416487
# Volume Up triggered
# Fist detected
# X movement: 0.011974650621414173
# Fist detected
# X movement: 0.012771058082580555
# Fist detected
# X movement: 0.01686255931854247
# Volume Up triggered
# Fist detected
# X movement: 0.018654501438140902
# Fist detected
# X movement: 0.02264028787612915
# Fist detected
# X movement: 0.018023061752319325
# Volume Up triggered
# Fist detected
# X movement: 0.029842960834503163
# Fist detected
# X movement: 0.026668864488601673
# Fist detected
# X movement: 0.028043591976165794
# Volume Up triggered
# Fist detected
# X movement: 0.028208494186401367
# Fist detected
# X movement: 0.027829837799072277
# Fist detected
# X movement: 0.02146250009536743
# Volume Up triggered
# Fist detected
# X movement: 0.025718992948532082
# Fist detected
# X movement: 0.025738680362701438
# Fist detected
# X movement: 0.02239691019058221
# Volume Up triggered
# Fist detected
# X movement: 0.030618667602539062
# Fist detected
# X movement: 0.025450730323791526
# Fist detected
# X movement: 0.021317255496978826
# Fist detected
# X movement: 0.02071492671966546
# Volume Up triggered
# Fist detected
# X movement: 0.023468518257141135
# Fist detected
# X movement: 0.015020775794982955
# Fist detected
# X movement: 0.019217860698699907
# Volume Up triggered
# Fist detected
# X movement: 0.023714506626129173
# Fist detected
# X movement: 0.02117886543273928
# Fist detected
# X movement: 0.01715011596679683
# Volume Up triggered
# Fist detected
# X movement: 0.016916751861572266
# Fist detected
# X movement: 0.011058068275451638
# Volume Up triggered
# Fist detected
# X movement: -0.0015706062316894753
# Fist detected
# X movement: -0.011255764961242587
# Volume Down triggered
# Fist detected
# X movement: -0.021781277656555242
# Fist detected
# X movement: -0.025210154056549028
# Fist detected
# X movement: -0.031451201438903786
# Volume Down triggered
# Fist detected
# X movement: -0.03371961116790778
# Fist detected
# X movement: -0.028636395931243896
# Fist detected
# X movement: -0.022556674480438188
# Volume Down triggered
# Fist detected
# X movement: -0.02505260705947876
# Fist detected
# X movement: -0.023201787471771262
# Fist detected
# X movement: -0.01880202293395994
# Volume Down triggered
# Fist detected
# X movement: -0.022188329696655296
# Fist detected
# X movement: -0.024155461788177512
# Fist detected
# X movement: -0.020485997200012207
# Volume Down triggered
# Fist detected
# X movement: -0.02205355763435357
# Fist detected
# X movement: -0.0224278867244721
# Fist detected
# X movement: -0.018272978067398082
# Volume Down triggered
# Fist detected
# X movement: -0.020557564496993974
# Fist detected
# X movement: -0.021037888526916515
# Fist detected
# X movement: -0.019699674844741832
# Volume Down triggered
# Fist detected
# X movement: -0.02334976792335508
# Fist detected
# X movement: -0.024144917726516724
# Fist detected
# X movement: -0.02045508623123171
# Volume Down triggered
# Fist detected
# X movement: -0.023856586217880227
# Fist detected
# X movement: -0.02385677397251129
# Fist detected
# X movement: -0.016787672042846702
# Volume Down triggered
# Fist detected
# X movement: -0.02087598741054536
# Fist detected
# X movement: -0.018922981619834883
# Fist detected
# X movement: -0.014668014645576488
# Volume Down triggered
# Fist detected
# X movement: -0.01261920332908631
# Fist detected
# X movement: -0.01202760636806488
# Fist detected
# X movement: -0.007394346594810475
# Volume Down triggered
# Fist detected
# X movement: -0.0054406195878982655
# Fist detected
# X movement: -0.0042695552110672
# Fist detected
# X movement: -0.0009215414524078314
# Fist detected
# X movement: 0.0001663416624069214
# Fist detected
# X movement: 0.002018201351165788
# Fist detected
# X movement: 0.00252682566642759
# Fist detected
# X movement: 0.002842316031456016
# Fist detected
# X movement: 0.0023555845022201483
# Fist detected
# X movement: 0.0019043415784835704
# Fist detected
# X movement: 0.0008099466562271063
# Fist detected
# X movement: 0.0006757318973541482
# Fist detected
# X movement: 0.0003661245107650646
# Fist detected
# X movement: 0.0004456818103790172
# Fist detected
# X movement: 0.0002595812082290816
# Fist detected
# X movement: 0.00025885999202726606
# Fist detected
# X movement: 0.0005593657493591364
# Fist detected
# X movement: 5.875825881959673e-05
# Fist detected
# X movement: -0.00015262961387635388
# Fist detected
# X movement: 8.440315723418079e-05
# Fist detected
# X movement: -7.777512073514625e-05
# Fist detected
# X movement: -6.816685199739769e-05
# Fist detected
# X movement: -0.00022191107273100696
# Fist detected
# X movement: 0.0002659946680068914
# Fist detected
# X movement: 0.0003654599189758245
# Fist detected
# X movement: 0.0009242206811904963
# Fist detected
# X movement: 0.004759725928306591
# Fist detected
# X movement: 0.006090423464775091
# Volume Up triggered
# Open palm detected: Play/Pause triggered
# Fist detected
# Fist detected
# X movement: -0.011911612749099743
# Volume Down triggered
# Open palm detected: Play/Pause triggered
# Index finger up detected: Fast forward 5 secs
# Index finger up detected: Fast forward 5 secs
# Index finger up detected: Fast forward 5 secs
# Index finger up detected: Fast forward 5 secs
# Index finger up detected: Fast forward 5 secs
# Index finger up detected: Fast forward 5 secs
# Index finger up detected: Fast forward 5 secs
# Open palm detected: Play/Pause triggered
# Thumb down detected: Rewind 5 secs
# Thumb down detected: Rewind 5 secs
# Thumb down detected: Rewind 5 secs
# Thumb down detected: Rewind 5 secs
# Thumb down detected: Rewind 5 secs
# Thumb down detected: Rewind 5 secs
# Fist detected
# Fist detected
# X movement: 0.006113621592521684
# Volume Up triggered
# Fist detected
# X movement: 0.0042953670024871715
# Fist detected
# X movement: 0.0012510061264038308
# Fist detected
# X movement: 0.0007396936416625977
# Fist detected
# X movement: -3.0899047851584704e-05
# Fist detected
# X movement: -0.00034249424934384987
# Fist detected
# X movement: -0.0010194420814514382
# Fist detected
# X movement: -0.0010037720203399658
# Fist detected
# X movement: -0.0009111702442169411
# Fist detected
# X movement: -0.0007087826728820468
# Fist detected
# X movement: -0.001755613088607777
# Fist detected
# X movement: -0.004378145933151278
# Index finger up detected: Fast forward 5 secs
# Index finger up detected: Fast forward 5 secs
# Index finger up detected: Fast forward 5 secs
# Open palm detected: Play/Pause triggered
# Fist detected
# Fist detected
# X movement: 0.0035212516784667858
# Fist detected
# X movement: 0.0045342594385147095
# Fist detected
# X movement: 0.004296523332595836
# Fist detected
# X movement: 0.004123067855834939
# Fist detected
# X movement: 0.0035130858421325573
# Fist detected
# X movement: 0.002555668354034424
# Fist detected
# X movement: 0.001416122913360629
# Fist detected
# X movement: 0.0011784613132476696
# Fist detected
# X movement: 0.0036432266235351674
# Fist detected
# X movement: 0.004567044973373402
# Fist detected
# X movement: 0.005397504568099953
# Volume Up triggered
# Fist detected
# X movement: 0.01333141922950748
# Fist detected
# X movement: 0.013740634918212868
# Fist detected
# X movement: 0.015659451484680176
# Volume Up triggered
# Fist detected
# X movement: 0.01922602653503419
# Fist detected
# X movement: 0.0194183528423309
# Fist detected
# X movement: 0.01250950098037723
# Fist detected
# X movement: 0.013232481479644786
# Fist detected
# X movement: 0.013402390480041493
# Volume Up triggered
# Fist detected
# X movement: 0.014596384763717662
# Fist detected
# X movement: 0.014557749032974243
# Fist detected
# X movement: 0.014629328250884976
# Fist detected
# X movement: 0.014234548807144198
# Volume Up triggered
# Fist detected
# X movement: 0.01815775632858274
# Fist detected
# X movement: 0.013084697723388716
# Fist detected
# X movement: 0.013215881586074785
# Fist detected
# X movement: 0.013114845752716042
# Fist detected
# X movement: 0.012918645143508933
# Volume Up triggered
# Fist detected
# X movement: 0.008935439586639449
# Fist detected
# X movement: 0.012111747264861972
# Fist detected
# X movement: 0.011166369915008634
# Fist detected
# X movement: 0.01064820289611812
# Volume Up triggered
# Fist detected
# X movement: 0.011695253849029585
# Fist detected
# X movement: 0.007167232036590532
# Fist detected
# X movement: 0.0034839749336242898
# Fist detected
# X movement: 0.0034439206123352273
# Fist detected
# X movement: 0.0031096696853637473
# Fist detected
# X movement: 0.001392400264739968
# Fist detected
# X movement: 0.0010555863380432573
# Fist detected
# X movement: 0.0007627010345458984
# Fist detected
# X movement: 0.00033762454986563384
# Fist detected
# X movement: -0.00011850595474238723
# Fist detected
# X movement: -0.0009471416473388894
# Fist detected
# X movement: -0.0012627840042114258
# Fist detected
# X movement: -0.0024795651435851607
# Fist detected
# X movement: -0.0029668450355530007
# Fist detected
# X movement: -0.005950295925140403
# Volume Down triggered
# Fist detected
# X movement: -0.01672075986862176
# Open palm detected: Play/Pause triggered
# Fist detected
# Fist detected
# X movement: -0.013271719217300415
# Volume Down triggered
# Fist detected
# X movement: -0.06370459198951717
# Volume Down triggered
# Fist detected
# X movement: -0.06088732779026035
# Fist detected
# X movement: -0.04323105216026307
# Open palm detected: Play/Pause triggered
# Fist detected
# Fist detected
# X movement: 0.003510063886642434
# Fist detected
# X movement: 0.003260678052902255
# Fist detected
# X movement: 0.0016097187995910422
# Fist detected
# X movement: 0.0004566609859466553
# Fist detected
# X movement: 0.0007032275199890248
# Fist detected
# X movement: 0.0008965551853180043
# Fist detected
# X movement: 0.001250958442687966
# Fist detected
# X movement: 0.0006360650062561257
# Fist detected
# X movement: -0.006120759248733509
# Volume Down triggered
# Fist detected
# X movement: -0.01732456684112549
# Volume Down triggered
# Fist detected
# X movement: -0.00658758878707888
# Open palm detected: Play/Pause triggered
# Fist detected
# Fist detected
# X movement: 0.0024210065603256226
# Fist detected
# X movement: 0.0010248690843582264
# Open palm detected: Play/Pause triggered
# Fist detected
# Fist detected
# X movement: 0.0032977283000946156
# Fist detected
# X movement: 0.0038020670413970725
# Fist detected
# X movement: 0.0035620033740997314
# Fist detected
# X movement: 0.003956604003906294
# Fist detected
# X movement: 0.0017446517944335604
# Fist detected
# X movement: 0.0015308320522308683
# Fist detected
# X movement: 0.0004357874393463024
# Fist detected
# X movement: -9.467601776125267e-05
# Fist detected
# X movement: -0.000340360403060902
# Fist detected
# X movement: -0.00014478564262387916
# Fist detected
# X movement: -0.00035632848739625134
# Fist detected
# X movement: -0.0004449725151062234
# Fist detected
# X movement: 0.00015613436698913574
# Fist detected
# X movement: 0.0008011400699615701
# Fist detected
# X movement: 0.001835370063781705
# Fist detected
# X movement: 0.00572437047958374
# Volume Up triggered
# Fist detected
# X movement: 0.010104286670684859
# Fist detected
# X movement: 0.015377527475357033
# Fist detected
# X movement: 0.01595997214317324
# Volume Up triggered
# Fist detected
# X movement: 0.023495090007781938
# Fist detected
# X movement: 0.020591711997985873
# Fist detected
# X movement: 0.017574441432952892
# Volume Up triggered
# Fist detected
# X movement: 0.02171158790588379
# Fist detected
# X movement: 0.021860712766647306
# Fist detected
# X movement: 0.01746550798416141
# Volume Up triggered
# Fist detected
# X movement: 0.020901310443878163
# Fist detected
# X movement: 0.02442550659179682
# Fist detected
# X movement: 0.01921699047088632
# Volume Up triggered
# Fist detected
# X movement: 0.021547597646713212
# Fist detected
# X movement: 0.02082668542861943
# Fist detected
# X movement: 0.016812157630920366
# Volume Up triggered
# Fist detected
# X movement: 0.017354941368103005
# Fist detected
# X movement: 0.012846040725708052
# Fist detected
# X movement: 0.011442649364471369
# Volume Up triggered
# Fist detected
# X movement: 0.010423505306243919
# Fist detected
# X movement: 0.013017058372497559
# Fist detected
# X movement: 0.008676135540008567
# Volume Up triggered
# Fist detected
# X movement: 0.009919857978820779
# Fist detected
# X movement: 0.0074340462684631126
# Fist detected
# X movement: 0.003933215141296409
# Fist detected
# X movement: 0.0006323814392089622
# Fist detected
# X movement: -0.0009108781814575195
# Fist detected
# X movement: -0.006920182704925448
# Volume Down triggered
# Fist detected
# X movement: -0.010385906696319669
# Fist detected
# X movement: -0.013778769969940097
# Fist detected
# X movement: -0.01447085142135629
# Volume Down triggered
# Fist detected
# X movement: -0.022599315643310525
# Fist detected
# X movement: -0.01981352567672723
# Fist detected
# X movement: -0.019446039199829124
# Volume Down triggered
# Fist detected
# X movement: -0.018608820438385076
# Fist detected
# X movement: -0.02023446559906006
# Fist detected
# X movement: -0.014983880519866877
# Volume Down triggered
# Fist detected
# X movement: -0.016297239065170332
# Fist detected
# X movement: -0.013560849428176813
# Fist detected
# X movement: -0.013148617744445867
# Volume Down triggered
# Fist detected
# X movement: -0.0142442405223846
# Fist detected
# X movement: -0.011806917190551769
# Fist detected
# X movement: -0.009548997879028354
# Fist detected
# X movement: -0.010054123401641801
# Volume Down triggered
# Fist detected
# X movement: -0.01429023146629338
# Fist detected
# X movement: -0.011202651262283314
# Fist detected
# X movement: -0.012737506628036466
# Fist detected
# X movement: -0.012882608175277754
# Volume Down triggered
# Fist detected
# X movement: -0.018202549219131448
# Fist detected
# X movement: -0.011706775426864602
# Fist detected
# X movement: -0.011928188800811812
# Fist detected
# X movement: -0.010065299272537187
# Volume Down triggered
# Fist detected
# X movement: -0.01606737375259404
# Fist detected
# X movement: -0.010355532169342041
# Fist detected
# X movement: -0.012598264217376698
# Volume Down triggered
# Fist detected
# X movement: -0.01497787833213804
# Fist detected
# X movement: -0.015412545204162631
# Fist detected
# X movement: -0.008314460515975952
# Volume Down triggered
# Fist detected
# X movement: -0.008357226848602295
# Fist detected
# X movement: -0.005582174658775307
# Fist detected
# X movement: -0.0024985730648040827
# Fist detected
# X movement: -0.002785277366638167
# Fist detected
# X movement: -0.003774368762969993
# Fist detected
# X movement: -0.003567117452621449
# Fist detected
# X movement: -0.004478463530540461
# Fist detected
# X movement: -0.004251390695571899
# Fist detected
# X movement: -0.0034291028976440596
# Fist detected
# X movement: -0.0024874418973922507
# Fist detected
# X movement: -0.0016217619180679543
# Fist detected
# X movement: -0.0003464430570602195
# Fist detected
# X movement: -0.0003784328699112105
# Fist detected
# X movement: 0.0003881186246872115
# Fist detected
# X movement: 0.0002718031406402366
# Fist detected
# X movement: 0.0001086950302124079
# Fist detected
# X movement: 0.00033023357391356867
# Fist detected
# X movement: 0.001126235723495489
# Fist detected
# X movement: 0.0017367422580719105
# Fist detected
# X movement: 0.00216006040573119
# Fist detected
# X movement: 0.0023433715105056763
# Fist detected
# X movement: 0.0026148140430450606
# Fist detected
# X movement: 0.0021540969610214233
# Fist detected
# X movement: 0.00185441374778747
# Fist detected
# X movement: 0.0026621431112289484
# Fist detected
# X movement: 0.002454000711441029
# Fist detected
# X movement: 0.0022523730993270763
# Fist detected
# X movement: 0.002751696109771745
# Fist detected
# X movement: 0.0028215378522872814
# Fist detected
# X movement: 0.00196653008460998
# Fist detected
# X movement: 0.0025167763233184814
# Fist detected
# X movement: 0.0046827256679535245
# Fist detected
# X movement: 0.005733060836791981
# Volume Up triggered
# Fist detected
# X movement: 0.0075554728507995494
# Open palm detected: Play/Pause triggered
# Index finger up detected: Fast forward 5 secs
# Open palm detected: Play/Pause triggered
# Index finger up detected: Fast forward 5 secs
# Index finger up detected: Fast forward 5 secs
# Index finger up detected: Fast forward 5 secs
# Index finger up detected: Fast forward 5 secs
# Index finger up detected: Fast forward 5 secs
# Index finger up detected: Fast forward 5 secs
# Open palm detected: Play/Pause triggered
# Thumb down detected: Rewind 5 secs
# Thumb down detected: Rewind 5 secs
# Thumb down detected: Rewind 5 secs
# Thumb down detected: Rewind 5 secs
# Thumb down detected: Rewind 5 secs
# Fist detected
# Fist detected
# X movement: 0.013051742315292325
# Volume Up triggered
# Fist detected
# X movement: 0.018800786137580905
# Fist detected
# X movement: 0.011807179450988747
# Fist detected
# X movement: 0.00988454818725587
# Fist detected
# X movement: 0.008820509910583474
# Volume Up triggered
# Fist detected
# X movement: 0.01076285839080815
# Fist detected
# X movement: 0.004430174827575684
# Fist detected
# X movement: 0.00465741753578186
# Fist detected
# X movement: 0.0054356098175048495
# Volume Up triggered
# Fist detected
# X movement: 0.00798531770706179
# Fist detected
# X movement: 0.00610063672065736
# Fist detected
# X movement: 0.006546092033386186
# Fist detected
# X movement: 0.009136229753494263
# Volume Up triggered
# Fist detected
# X movement: 0.010014253854751631
# Fist detected
# X movement: 0.00739625096321106
# Fist detected
# X movement: 0.006952565908431962
# Fist detected
# X movement: 0.008917206525802635
# Volume Up triggered
# Fist detected
# X movement: 0.008381569385528587
# Fist detected
# X movement: 0.006017863750457764
# Fist detected
# X movement: 0.006212741136550903
# Fist detected
# X movement: 0.00653170347213744
# Fist detected
# X movement: 0.003455156087875333
# Fist detected
# X movement: 0.0007449626922607644
# Fist detected
# X movement: 0.0008645772933960072
# Fist detected
# X movement: 0.00016589760780333362
# Fist detected
# X movement: -0.0009897232055663951
# Fist detected
# X movement: -0.0010352015495300182
# Fist detected
# X movement: -0.0008773267269134855
# Index finger up detected: Fast forward 5 secs
# Open palm detected: Play/Pause triggered
# Index finger up detected: Fast forward 5 secs
# Index finger up detected: Fast forward 5 secs
# Index finger up detected: Fast forward 5 secs
# Index finger up detected: Fast forward 5 secs
# Index finger up detected: Fast forward 5 secs
# Open palm detected: Play/Pause triggered
# Quitting program
