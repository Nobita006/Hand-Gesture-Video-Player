# %%
# %pip install opencv-python mediapipe pyautogui
# Out:
# Requirement already satisfied: opencv-python in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (4.10.0.84)
# Requirement already satisfied: mediapipe in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (0.10.14)
# Requirement already satisfied: pyautogui in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (0.9.54)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from opencv-python) (2.0.1)
# Requirement already satisfied: absl-py in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from mediapipe) (2.1.0)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from mediapipe) (24.2.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from mediapipe) (24.3.25)
# Requirement already satisfied: jax in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from mediapipe) (0.4.31)
# Requirement already satisfied: jaxlib in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from mediapipe) (0.4.31)
# Requirement already satisfied: matplotlib in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from mediapipe) (3.9.2)
# Requirement already satisfied: opencv-contrib-python in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from mediapipe) (4.10.0.84)
# Requirement already satisfied: protobuf<5,>=4.25.3 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from mediapipe) (4.25.4)
# Requirement already satisfied: sounddevice>=0.4.4 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from mediapipe) (0.5.0)
# Requirement already satisfied: pymsgbox in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from pyautogui) (1.0.9)
# Requirement already satisfied: pytweening>=1.0.4 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from pyautogui) (1.2.0)
# Requirement already satisfied: pyscreeze>=0.1.21 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from pyautogui) (0.1.30)
# Requirement already satisfied: pygetwindow>=0.0.5 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from pyautogui) (0.0.9)
# Requirement already satisfied: mouseinfo in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from pyautogui) (0.1.3)
# Requirement already satisfied: pyrect in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from pygetwindow>=0.0.5->pyautogui) (0.2.0)
# Requirement already satisfied: CFFI>=1.0 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from sounddevice>=0.4.4->mediapipe) (1.17.0)
# Requirement already satisfied: ml-dtypes>=0.2.0 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from jax->mediapipe) (0.4.0)
# Requirement already satisfied: opt-einsum in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from jax->mediapipe) (3.3.0)
# Requirement already satisfied: scipy>=1.10 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from jax->mediapipe) (1.14.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mediapipe) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mediapipe) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mediapipe) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\sayan\appdata\roaming\python\python312\site-packages (from matplotlib->mediapipe) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mediapipe) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mediapipe) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sayan\appdata\roaming\python\python312\site-packages (from matplotlib->mediapipe) (2.9.0.post0)
# Requirement already satisfied: pyperclip in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from mouseinfo->pyautogui) (1.9.0)
# Requirement already satisfied: pycparser in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.22)
# Requirement already satisfied: six>=1.5 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Import Libraries and Set Up Hand Detection

# %%
import cv2
import mediapipe as mp
import pyautogui
import time
import numpy as np
from collections import deque

# Initialize Mediapipe hand detection with higher confidence thresholds
mp_hands = mp.solutions.hands
hands = mp_hands.Hands(max_num_hands=1, min_detection_confidence=0.8, min_tracking_confidence=0.8)
mp_draw = mp.solutions.drawing_utils

# Variables for delay management
last_play_pause_time = time.time()
last_volume_change_time = time.time()
last_gesture_time = time.time()

# Thresholds
play_pause_delay = 1  # 1 second delay for play/pause
volume_change_delay = 0.2  # 1/5 second delay for volume change
gesture_delay = 1  # 1 second delay for gestures
movement_threshold = 0.005  # adjust threshold for detecting meaningful fist movements

# Gesture States
is_open_palm = False
is_fist = False
previous_fist_position = None
debug_text = ""  # Text to display on the video feed

# Frame rate control
target_fps = 24
frame_duration = 1.0 / target_fps

# Smoothing settings
smoothing_window_size = 5
landmark_queue = deque(maxlen=smoothing_window_size)

# Capture video from webcam
cap = cv2.VideoCapture(0)

def is_open_palm_landmarks(landmarks):
    return landmarks[8][1] < landmarks[6][1] and \
           landmarks[12][1] < landmarks[10][1] and \
           landmarks[16][1] < landmarks[14][1] and \
           landmarks[20][1] < landmarks[18][1]

def is_fist_landmarks(landmarks):
    return landmarks[8][1] > landmarks[6][1] and \
           landmarks[12][1] > landmarks[10][1] and \
           landmarks[16][1] > landmarks[14][1] and \
           landmarks[20][1] > landmarks[18][1]

def is_index_finger_pointing_up(landmarks):
    return landmarks[8][1] < landmarks[6][1] and \
           landmarks[12][1] > landmarks[10][1] and \
           landmarks[16][1] > landmarks[14][1] and \
           landmarks[20][1] > landmarks[18][1]

def is_thumb_down(landmarks):
    return landmarks[4][1] > landmarks[3][1] and \
           landmarks[8][1] < landmarks[6][1] and \
           landmarks[12][1] < landmarks[10][1] and \
           landmarks[16][1] < landmarks[14][1] and \
           landmarks[20][1] < landmarks[18][1]

def get_fist_direction(current_position, previous_position):
    if current_position is not None and previous_position is not None:
        x_movement = current_position[0] - previous_position[0]
        return x_movement
    return None

def smooth_landmarks(landmarks):
    landmark_queue.append(landmarks)
    avg_landmarks = np.mean(landmark_queue, axis=0)
    return avg_landmarks

while cap.isOpened():
    start_time = time.time()

    success, frame = cap.read()
    if not success:
        print("Failed to capture frame")
        break
    
    # Convert the image to RGB
    image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    image.flags.writeable = False
    
    # Process the image and detect hands
    results = hands.process(image)
    image.flags.writeable = True
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    
    if results.multi_hand_landmarks:
        for hand_landmarks in results.multi_hand_landmarks:
            # Convert landmarks to numpy array for smoothing
            landmarks_array = np.array([(lm.x, lm.y, lm.z) for lm in hand_landmarks.landmark])
            
            # Smooth the landmarks
            smoothed_landmarks = smooth_landmarks(landmarks_array)
            
            # Check if the hand is open palm
            if is_open_palm_landmarks(smoothed_landmarks):
                if not is_open_palm and (time.time() - last_play_pause_time) > play_pause_delay:
                    debug_text = "Open palm detected: Play/Pause triggered"
                    print(debug_text)
                    pyautogui.press('space')
                    last_play_pause_time = time.time()
                    is_open_palm = True
                is_fist = False  # Reset fist status
            else:
                is_open_palm = False
            
            # Check if the hand is in a fist
            if is_fist_landmarks(smoothed_landmarks):
                debug_text = "Fist detected"
                print(debug_text)
                current_position = smoothed_landmarks[9]  # Use landmark 9 as reference for fist position
                if is_fist and previous_fist_position is not None:
                    x_movement = get_fist_direction(current_position, previous_fist_position)
                    if x_movement:
                        debug_text = f"X movement: {x_movement}"
                        print(debug_text)
                        if x_movement < -movement_threshold and (time.time() - last_volume_change_time) > volume_change_delay:
                            debug_text = "Volume Down triggered"
                            print(debug_text)
                            pyautogui.press('volumedown')
                            last_volume_change_time = time.time()
                        elif x_movement > movement_threshold and (time.time() - last_volume_change_time) > volume_change_delay:
                            debug_text = "Volume Up triggered"
                            print(debug_text)
                            pyautogui.press('volumeup')
                            last_volume_change_time = time.time()
                is_fist = True
                previous_fist_position = current_position  # Update the previous fist position
            else:
                is_fist = False

            # Check for index finger pointing up
            if is_index_finger_pointing_up(smoothed_landmarks) and (time.time() - last_gesture_time) > gesture_delay:
                debug_text = "Index finger up detected: Fast forward 5 secs"
                print(debug_text)
                pyautogui.press('right')
                last_gesture_time = time.time()

            # Check for thumb down
            if is_thumb_down(smoothed_landmarks) and (time.time() - last_gesture_time) > gesture_delay:
                debug_text = "Thumb down detected: Rewind 5 secs"
                print(debug_text)
                pyautogui.press('left')
                last_gesture_time = time.time()

            # Draw hand landmarks
            mp_draw.draw_landmarks(image, hand_landmarks, mp_hands.HAND_CONNECTIONS)

            # Display the debug text on the video feed
            cv2.putText(image, debug_text, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2, cv2.LINE_AA)
    
    # Display the video feed
    cv2.imshow('Hand Gesture Control', image)
    
    # Break loop with 'q' key
    if cv2.waitKey(1) & 0xFF == ord('q'):
        print("Quitting program")
        break

    # Frame rate control
    end_time = time.time()
    elapsed_time = end_time - start_time
    if elapsed_time < frame_duration:
        time.sleep(frame_duration - elapsed_time)

cap.release()
cv2.destroyAllWindows()
# Out:
# c:\Users\sayan\AppData\Local\Programs\Python\Python312\Lib\site-packages\google\protobuf\symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# Open palm detected: Play/Pause triggered
# Index finger up detected: Fast forward 5 secs
# Index finger up detected: Fast forward 5 secs
# Fist detected
# Fist detected
# X movement: -0.015978074073791537
# Volume Down triggered
# Fist detected
# X movement: -0.016061145067214955
# Fist detected
# X movement: -0.00845850706100465
# Fist detected
# X movement: -0.007843089103698742
# Fist detected
# X movement: -0.008766871690750078
# Fist detected
# X movement: -0.0006581008434295987
# Fist detected
# X movement: -0.00038413405418397106
# Fist detected
# X movement: -0.0007724463939666748
# Fist detected
# X movement: -0.0006222844123839888
# Fist detected
# X movement: -0.0004913330078125111
# Fist detected
# X movement: -9.423494338989258e-05
# Fist detected
# X movement: -8.64565372467041e-05
# Fist detected
# X movement: 0.00021626949310299404
# Fist detected
# X movement: 2.5856494903608862e-05
# Fist detected
# X movement: -0.00016118884086613328
# Fist detected
# X movement: -0.0001164257526397594
# Fist detected
# X movement: 0.0003831446170807218
# Fist detected
# X movement: 0.0002579331398009921
# Fist detected
# X movement: 0.00029250383377077416
# Fist detected
# X movement: 8.13603401184082e-05
# Fist detected
# X movement: 0.0001783013343810702
# Fist detected
# X movement: -0.0003533303737640048
# Fist detected
# X movement: -0.00042408108711244896
# Fist detected
# X movement: -0.00038244128227232776
# Fist detected
# X movement: -0.00020974278450014427
# Fist detected
# X movement: 0.0011375486850738747
# Fist detected
# X movement: 0.0005875289440154807
# Fist detected
# X movement: 0.0005952715873718262
# Fist detected
# X movement: 0.00490464568138127
# Fist detected
# X movement: 0.006107145547866788
# Volume Up triggered
# Fist detected
# X movement: 0.014570605754852306
# Fist detected
# X movement: 0.015697616338729847
# Fist detected
# X movement: 0.017664653062820446
# Fist detected
# X movement: 0.013320440053939842
# Volume Up triggered
# Fist detected
# X movement: 0.012220871448516801
# Fist detected
# X movement: 0.0019304096698761208
# Fist detected
# X movement: 0.0012420654296875222
# Fist detected
# X movement: -0.0008173167705536333
# Fist detected
# X movement: -0.0008694410324096569
# Fist detected
# X movement: -0.0007364749908447266
# Fist detected
# X movement: -0.00035241246223449707
# Fist detected
# X movement: -0.0008988380432128906
# Fist detected
# X movement: -0.002474999427795388
# Fist detected
# X movement: -0.002331632375717152
# Fist detected
# X movement: -0.0024514198303222656
# Fist detected
# X movement: -0.004102426767349288
# Fist detected
# X movement: -0.003335839509963967
# Fist detected
# X movement: -0.0016079366207122914
# Fist detected
# X movement: -0.0021789789199829213
# Fist detected
# X movement: -0.002697324752807595
# Fist detected
# X movement: -0.0010506391525268444
# Fist detected
# X movement: -0.0010746657848358376
# Fist detected
# X movement: -0.001231372356414795
# Fist detected
# X movement: -0.0007095575332641268
# Fist detected
# X movement: -4.1437149047862665e-05
# Fist detected
# X movement: 5.5283308029174805e-05
# Fist detected
# X movement: -6.765127182006836e-06
# Fist detected
# X movement: 0.0008103847503662109
# Fist detected
# X movement: 0.0013396322727203258
# Fist detected
# X movement: 0.0014265120029449685
# Fist detected
# X movement: 0.001380103826522816
# Fist detected
# X movement: 0.00262445807456968
# Fist detected
# X movement: 0.0016836881637573575
# Fist detected
# X movement: 0.0012400805950164573
# Fist detected
# X movement: 0.0026582241058349387
# Fist detected
# X movement: 0.0039922654628753995
# Fist detected
# X movement: 0.002049785852432262
# Fist detected
# X movement: 0.0023744225502013716
# Fist detected
# X movement: 0.0033213913440704457
# Fist detected
# X movement: 0.0026410758495331033
# Fist detected
# X movement: 0.001277667284011852
# Fist detected
# X movement: 0.0018752574920654075
# Fist detected
# X movement: 0.0024898231029510387
# Fist detected
# X movement: 0.0015851080417633168
# Fist detected
# X movement: 0.002030944824218728
# Fist detected
# X movement: 0.0017712056636810525
# Fist detected
# X movement: 0.0018372476100921853
# Fist detected
# X movement: 0.0023144662380218395
# Fist detected
# X movement: 0.0019186198711395042
# Fist detected
# X movement: 0.00058618783950809
# Fist detected
# X movement: 0.001950329542160012
# Fist detected
# X movement: 0.0026617050170898438
# Fist detected
# X movement: 0.0015519917011260764
# Fist detected
# X movement: 0.0017923295497894731
# Fist detected
# X movement: 0.001251256465911843
# Fist detected
# X movement: 0.00021196603775025524
# Index finger up detected: Fast forward 5 secs
# Index finger up detected: Fast forward 5 secs
# Index finger up detected: Fast forward 5 secs
# Index finger up detected: Fast forward 5 secs
# Index finger up detected: Fast forward 5 secs
# Fist detected
# Fist detected
# X movement: -0.00945785641670227
# Volume Down triggered
# Fist detected
# X movement: -0.005554527044296265
# Open palm detected: Play/Pause triggered
# Fist detected
# Fist detected
# X movement: -0.0005967020988464355
# Fist detected
# X movement: -0.0003503680229187123
# Fist detected
# X movement: -0.0012136101722717285
# Fist detected
# X movement: -0.0010136425495147483
# Fist detected
# X movement: -0.0013705790042877197
# Fist detected
# X movement: -0.00019477009773255505
# Fist detected
# X movement: 1.4793872833263055e-05
# Fist detected
# X movement: 0.0002037346363067405
# Fist detected
# X movement: 0.00022202134132387474
# Fist detected
# X movement: 0.0003732442855834961
# Fist detected
# X movement: 0.00023670196533204235
# Fist detected
# X movement: 0.000878566503524747
# Fist detected
# X movement: 0.0005225896835327482
# Fist detected
# X movement: 0.0005751252174377441
# Fist detected
# X movement: 0.0011494159698486328
# Fist detected
# X movement: 0.0012511372566222922
# Fist detected
# X movement: 0.0014700055122375266
# Fist detected
# X movement: 0.001547527313232433
# Fist detected
# X movement: 0.0017332315444946178
# Fist detected
# X movement: -0.006775009632110585
# Volume Down triggered
# Fist detected
# X movement: -0.008783435821533181
# Open palm detected: Play/Pause triggered
# Open palm detected: Play/Pause triggered
# Index finger up detected: Fast forward 5 secs
# Fist detected
# Fist detected
# X movement: -0.0008923590183257946
# Open palm detected: Play/Pause triggered
# Index finger up detected: Fast forward 5 secs
# Index finger up detected: Fast forward 5 secs
# Open palm detected: Play/Pause triggered
# Index finger up detected: Fast forward 5 secs
# Index finger up detected: Fast forward 5 secs
# Index finger up detected: Fast forward 5 secs
# Index finger up detected: Fast forward 5 secs
# Index finger up detected: Fast forward 5 secs
# Index finger up detected: Fast forward 5 secs
# Index finger up detected: Fast forward 5 secs
# Index finger up detected: Fast forward 5 secs
# Index finger up detected: Fast forward 5 secs
# Index finger up detected: Fast forward 5 secs
# Index finger up detected: Fast forward 5 secs
# Index finger up detected: Fast forward 5 secs
# Fist detected
# Fist detected
# X movement: -0.006113457679748524
# Volume Down triggered
# Fist detected
# X movement: 0.0031476765871047974
# Fist detected
# X movement: 0.002536574006080594
# Fist detected
# X movement: 0.0029176175594329834
# Fist detected
# X movement: 0.0023679047822952604
# Fist detected
# X movement: 0.0005624055862426536
# Fist detected
# X movement: 0.0003042280673981046
# Fist detected
# X movement: 0.0005737841129302979
# Fist detected
# X movement: 0.0003108203411101851
# Fist detected
# X movement: 0.0004227399826050027
# Fist detected
# X movement: 0.00024008750915527344
# Fist detected
# X movement: 0.00016977190971373401
# Fist detected
# X movement: -6.157159805297852e-05
# Fist detected
# X movement: 3.7682056427013055e-05
# Fist detected
# X movement: 0.00015492439270020641
# Fist detected
# X movement: 0.00029495954513547584
# Fist detected
# X movement: 0.00037253499031070225
# Fist detected
# X movement: 0.0016544818878173606
# Fist detected
# X movement: 0.0017501175403594749
# Fist detected
# X movement: 0.0014903843402862549
# Index finger up detected: Fast forward 5 secs
# Open palm detected: Play/Pause triggered
# Open palm detected: Play/Pause triggered
# Thumb down detected: Rewind 5 secs
# Thumb down detected: Rewind 5 secs
# Thumb down detected: Rewind 5 secs
# Thumb down detected: Rewind 5 secs
# Thumb down detected: Rewind 5 secs
# Thumb down detected: Rewind 5 secs
# Thumb down detected: Rewind 5 secs
# Thumb down detected: Rewind 5 secs
# Thumb down detected: Rewind 5 secs
# Thumb down detected: Rewind 5 secs
# Thumb down detected: Rewind 5 secs
# Thumb down detected: Rewind 5 secs
# Thumb down detected: Rewind 5 secs
# Thumb down detected: Rewind 5 secs
# Thumb down detected: Rewind 5 secs
# Index finger up detected: Fast forward 5 secs
# Fist detected
# Fist detected
# X movement: -0.010971319675445568
# Volume Down triggered
# Fist detected
# X movement: -0.012964457273483276
# Fist detected
# X movement: -0.01297003626823423
# Fist detected
# X movement: -0.01431688666343689
# Fist detected
# X movement: -0.0054403901100159024
# Volume Down triggered
# Fist detected
# X movement: -0.0015040338039398193
# Fist detected
# X movement: 0.0023656666278839
# Fist detected
# X movement: 0.0018703758716583363
# Fist detected
# X movement: 0.003172987699508689
# Fist detected
# X movement: 0.0008852899074554554
# Fist detected
# X movement: 0.0014373838901519664
# Fist detected
# X movement: -0.00013497471809387207
# Fist detected
# X movement: -7.620453834533691e-05
# Fist detected
# X movement: -0.00042076706886290394
# Fist detected
# X movement: -0.0007473945617675892
# Fist detected
# X movement: -0.0006839156150817982
# Fist detected
# X movement: -9.607672691347435e-05
# Fist detected
# X movement: 0.00030258893966678135
# Fist detected
# X movement: 0.0006174147129058838
# Fist detected
# X movement: 0.0006055533885955811
# Fist detected
# X movement: 0.00010625720024109997
# Fist detected
# X movement: -0.0003090679645538774
# Fist detected
# X movement: -0.0003092348575591819
# Fist detected
# X movement: -0.0004689514636993519
# Fist detected
# X movement: -0.0005932092666625643
# Fist detected
# X movement: -0.00018310546875
# Fist detected
# X movement: -0.00026056766510013096
# Fist detected
# X movement: -0.0002857983112334872
# Fist detected
# X movement: 9.159445762629836e-05
# Fist detected
# X movement: 0.00033082962036135033
# Fist detected
# X movement: 0.00042713284492490455
# Fist detected
# X movement: 0.0008374154567718506
# Fist detected
# X movement: 0.0009185194969177357
# Fist detected
# X movement: 0.0004270732402801847
# Fist detected
# X movement: 0.0003378570079803356
# Fist detected
# X movement: 0.00034648776054380104
# Fist detected
# X movement: -7.696151733399548e-05
# Fist detected
# X movement: -0.00015982389450069912
# Fist detected
# X movement: -0.0004148066043853649
# Fist detected
# X movement: -0.0013290107250213956
# Fist detected
# X movement: -0.0014743804931640625
# Fist detected
# X movement: -0.0014222085475921742
# Fist detected
# X movement: -0.0006304860115051159
# Fist detected
# X movement: 2.2143125534057617e-05
# Fist detected
# X movement: 0.0006185710430145486
# Fist detected
# X movement: 0.0005803704261779785
# Fist detected
# X movement: 0.000416654348373402
# Fist detected
# X movement: -0.0015073895454406627
# Fist detected
# X movement: -0.001900959014892567
# Fist detected
# X movement: -0.0018052875995636097
# Fist detected
# X movement: -0.0034169554710388184
# Fist detected
# X movement: -0.0036897420883179044
# Fist detected
# X movement: -0.0027342081069945956
# Fist detected
# X movement: -0.0024390637874603383
# Fist detected
# X movement: -0.0018446505069732444
# Fist detected
# X movement: 0.0002615034580230602
# Fist detected
# X movement: 0.0006517171859741211
# Fist detected
# X movement: 0.0007548332214355469
# Fist detected
# X movement: 0.0008305847644805575
# Fist detected
# X movement: 0.0003935217857360951
# Fist detected
# X movement: 2.443194389345482e-05
# Fist detected
# X movement: -0.00012006163597105823
# Fist detected
# X movement: -4.8512220382712634e-05
# Fist detected
# X movement: -0.0006817400455474965
# Fist detected
# X movement: -0.0009112596511840487
# Fist detected
# X movement: -0.001037913560867354
# Fist detected
# X movement: -0.000927007198333718
# Fist detected
# X movement: -0.0010875463485717773
# Fist detected
# X movement: -0.0006615519523620605
# Fist detected
# X movement: -0.0004880368709564431
# Fist detected
# X movement: -0.0004407346248626598
# Fist detected
# X movement: -0.00048696398735043056
# Fist detected
# X movement: -0.00037376880645756394
# Fist detected
# X movement: -0.0002931237220764049
# Fist detected
# X movement: 0.00018966197967529297
# Fist detected
# X movement: 0.0004136919975281095
# Fist detected
# X movement: 0.00039838552474974476
# Fist detected
# X movement: -0.0006715655326843262
# Fist detected
# X movement: -0.0007198929786682018
# Fist detected
# X movement: -0.0013400614261627197
# Fist detected
# X movement: -0.001406824588775668
# Fist detected
# X movement: -0.0013821125030517578
# Fist detected
# X movement: -0.00031940340995789684
# Fist detected
# X movement: -0.0002320706844329834
# Fist detected
# X movement: -3.237724304194778e-05
# Fist detected
# X movement: 5.8710575103759766e-06
# Fist detected
# X movement: 5.640983581539638e-05
# Fist detected
# X movement: 2.8288364410433697e-05
# Fist detected
# X movement: 4.6712160110429224e-05
# Fist detected
# X movement: -0.0029731035232543612
# Fist detected
# X movement: -0.0038388133049011286
# Fist detected
# X movement: -0.010315191745758068
# Volume Down triggered
# Fist detected
# X movement: -0.0157724678516388
# Fist detected
# X movement: -0.015527203679084778
# Fist detected
# X movement: -0.014622211456298828
# Fist detected
# X movement: -0.013221198320388788
# Fist detected
# X movement: -0.0071615189313888605
# Fist detected
# X movement: -0.0014472961425781028
# Fist detected
# X movement: -0.00046282112598419745
# Fist detected
# X movement: 0.001972544193267811
# Fist detected
# X movement: 0.0014152050018310658
# Fist detected
# X movement: 0.001072373986244185
# Fist detected
# X movement: 0.0029092878103256226
# Fist detected
# X movement: 0.0019106388092041127
# Fist detected
# X movement: 0.0016209572553634588
# Fist detected
# X movement: 0.0027306199073791615
# Fist detected
# X movement: 0.0035161644220352006
# Fist detected
# X movement: 0.0014704883098602406
# Fist detected
# X movement: 0.0012022644281387274
# Fist detected
# X movement: 0.0023740321397781317
# Fist detected
# X movement: 0.04262033700942994
# Volume Up triggered
# Fist detected
# X movement: 0.04101897180080413
# Fist detected
# X movement: 0.04141490757465366
# Fist detected
# X movement: 0.03823786675930019
# Fist detected
# X movement: 0.03671502470970156
# Fist detected
# X movement: -0.005254960060119607
# Volume Down triggered
# Fist detected
# X movement: -0.00569385290145874
# Fist detected
# X movement: -0.006006938219070446
# Fist detected
# X movement: -0.0028825223445892445
# Fist detected
# X movement: 0.0015722572803497092
# Fist detected
# X movement: 0.001903849840164229
# Fist detected
# X movement: 0.0034813821315765048
# Fist detected
# X movement: 0.0032780110836029275
# Fist detected
# X movement: 0.005667912960052479
# Volume Up triggered
# Fist detected
# X movement: 0.0011530637741088978
# Fist detected
# X movement: 0.001550137996673584
# Fist detected
# X movement: 0.0020627439022063987
# Fist detected
# X movement: 0.003205084800720237
# Fist detected
# X movement: 0.00011322498321530983
# Fist detected
# X movement: 0.00038306117057801403
# Fist detected
# X movement: 0.00035406947135924183
# Fist detected
# X movement: -0.0007617950439453014
# Fist detected
# X movement: -0.002026110887527466
# Fist detected
# X movement: -0.0009951114654541127
# Fist detected
# X movement: -0.000108903646469094
# Fist detected
# X movement: -0.00034308433532714844
# Fist detected
# X movement: -0.0007516086101532204
# Fist detected
# X movement: -0.00029668211936950684
# Fist detected
# X movement: -0.0005456447601318026
# Fist detected
# X movement: -2.5397539138827252e-05
# Fist detected
# X movement: 0.0002629816532135343
# Fist detected
# X movement: 0.0017020821571349654
# Fist detected
# X movement: 0.0015998840332031583
# Fist detected
# X movement: 0.0008658766746520996
# Fist detected
# X movement: -0.0004110693931579923
# Fist detected
# X movement: -0.00029034018516538307
# Fist detected
# X movement: -0.0002048194408416637
# Fist detected
# X movement: -0.0007441699504852628
# Fist detected
# X movement: -0.00040715932846069336
# Fist detected
# X movement: -0.0003410935401916282
# Fist detected
# X movement: 7.958412170411266e-05
# Fist detected
# X movement: 4.777908325193092e-05
# Fist detected
# X movement: 0.0005195319652557262
# Fist detected
# X movement: 0.0010059833526611661
# Fist detected
# X movement: 0.0007394134998321422
# Fist detected
# X movement: -0.0004017651081085205
# Fist detected
# X movement: -0.0005276739597320779
# Fist detected
# X movement: -0.0006433010101318248
# Fist detected
# X movement: -7.705092430115856e-05
# Fist detected
# X movement: 0.0006907880306243896
# Fist detected
# X movement: 0.0014247596263885498
# Fist detected
# X movement: 0.0017298817634582853
# Fist detected
# X movement: 0.0018886744976043812
# Fist detected
# X movement: 0.0012907147407531516
# Fist detected
# X movement: 0.0012760400772094949
# Fist detected
# X movement: 0.0011072576045989546
# Fist detected
# X movement: -0.00012074708938597523
# Fist detected
# X movement: -3.739595413204677e-05
# Fist detected
# X movement: -0.00010682940483097703
# Fist detected
# X movement: -0.0008403003215789462
# Fist detected
# X movement: -0.0008498489856720304
# Fist detected
# X movement: 4.4637918472312244e-05
# Fist detected
# X movement: -6.824731826782227e-05
# Fist detected
# X movement: -0.00013494491577148438
# Fist detected
# X movement: 0.0004725515842437522
# Fist detected
# X movement: 0.00019176006317139782
# Fist detected
# X movement: 0.00023117661476135254
# Fist detected
# X movement: 0.00019584298133851208
# Fist detected
# X movement: 0.00018137097358705834
# Fist detected
# X movement: -0.0002478361129760742
# Fist detected
# X movement: 0.000208604335784901
# Fist detected
# X movement: 0.0004062950611114502
# Fist detected
# X movement: 0.0005505979061126709
# Fist detected
# X movement: 0.0007793664932250755
# Fist detected
# X movement: 0.0007779419422149769
# Fist detected
# X movement: -0.00017690658569335938
# Fist detected
# X movement: -0.0003890395164489746
# Fist detected
# X movement: -0.00043615102767946556
# Fist detected
# X movement: -0.00038498640060424805
# Fist detected
# X movement: -0.0005327165126800537
# Fist detected
# X movement: -0.00011044144630428798
# Fist detected
# X movement: -0.0001827239990234708
# Fist detected
# X movement: -0.0002765655517578125
# Fist detected
# X movement: 0.0019703030586242787
# Fist detected
# X movement: 0.0024741053581238126
# Fist detected
# X movement: 0.003062993288040161
# Fist detected
# X movement: 0.0031710982322692427
# Fist detected
# X movement: 0.0017867267131805864
# Fist detected
# X movement: -0.0004926800727844682
# Fist detected
# X movement: -0.0011027097702026034
# Fist detected
# X movement: -0.002149808406829823
# Fist detected
# X movement: -0.0013681352138519287
# Fist detected
# X movement: -3.557801246645287e-05
# Fist detected
# X movement: -5.4222345352183954e-05
# Fist detected
# X movement: 0.0003231465816497803
# Fist detected
# X movement: 0.0013796687126159668
# Fist detected
# X movement: 0.0010018825531005748
# Fist detected
# X movement: 0.0011703848838806596
# Fist detected
# X movement: 0.001218628883361772
# Fist detected
# X movement: 0.00036714673042298474
# Fist detected
# X movement: -0.0011046886444091575
# Fist detected
# X movement: -0.001781243085861195
# Fist detected
# X movement: -0.0019601345062256192
# Fist detected
# X movement: -0.0016847431659698375
# Fist detected
# X movement: -0.00048700571060178444
# Fist detected
# X movement: 0.0005856454372406006
# Fist detected
# X movement: 0.00016069412231445312
# Fist detected
# X movement: -7.855892181440893e-06
# Fist detected
# X movement: 2.8401613235473633e-05
# Fist detected
# X movement: -0.00019292831420897327
# Fist detected
# X movement: -0.00031027793884275123
# Fist detected
# X movement: 0.00017293095588682972
# Fist detected
# X movement: 0.0002712070941924827
# Fist detected
# X movement: -0.0002099633216857688
# Fist detected
# X movement: 8.853673934938744e-05
# Fist detected
# X movement: 0.0002937614917755127
# Fist detected
# X movement: 0.0007379055023193359
# Fist detected
# X movement: 0.0007616400718688521
# Fist detected
# X movement: 0.000707662105560336
# Fist detected
# X movement: 0.0009975016117095836
# Fist detected
# X movement: 0.0009363293647766113
# Fist detected
# X movement: 0.0014452993869781272
# Fist detected
# X movement: 0.0014144241809845304
# Fist detected
# X movement: 0.0008584916591644065
# Fist detected
# X movement: -0.00019171833992004395
# Fist detected
# X movement: 0.00034276247024539463
# Fist detected
# X movement: -0.0014844775199890359
# Fist detected
# X movement: -0.0010521531105041615
# Fist detected
# X movement: -0.0008752763271331898
# Fist detected
# X movement: -8.05675983428511e-05
# Fist detected
# X movement: -0.0009285569190979337
# Fist detected
# X movement: 6.254315376280628e-05
# Fist detected
# X movement: -0.0003468513488769087
# Fist detected
# X movement: 1.8501281738247943e-05
# Fist detected
# X movement: -0.0009743332862853782
# Fist detected
# X movement: -0.00030002593994143956
# Fist detected
# X movement: -0.00023695826530456543
# Fist detected
# X movement: -0.0001977384090423584
# Fist detected
# X movement: 6.881952285769932e-05
# Fist detected
# X movement: 0.00037410855293273926
# Fist detected
# X movement: -5.88834285736306e-05
# Fist detected
# X movement: -9.357929229736328e-05
# Fist detected
# X movement: 0.0002584993839264138
# Fist detected
# X movement: -4.693269729616478e-05
# Fist detected
# X movement: -0.0001652836799621582
# Fist detected
# X movement: 0.00042204856872557484
# Fist detected
# X movement: 0.0005059361457824818
# Fist detected
# X movement: 0.0003704190254211759
# Fist detected
# X movement: 0.0002398550510406272
# Fist detected
# X movement: 0.0006385326385497936
# Fist detected
# X movement: -0.0003085196018218772
# Fist detected
# X movement: -0.00031355619430545323
# Fist detected
# X movement: -0.0003836512565612571
# Fist detected
# X movement: -0.0003538668155670388
# Fist detected
# X movement: -0.00037273168563839443
# Fist detected
# X movement: 1.7750263214100226e-05
# Fist detected
# X movement: -8.219480514548572e-06
# Fist detected
# X movement: 0.00010883808135986328
# Fist detected
# X movement: 3.365874290467419e-05
# Fist detected
# X movement: 0.00015094876289367676
# Fist detected
# X movement: 6.272196769713245e-05
# Fist detected
# X movement: 0.0006600618362426758
# Fist detected
# X movement: 0.0006189107894897794
# Fist detected
# X movement: 0.0009837388992309237
# Fist detected
# X movement: 0.0006856977939606046
# Fist detected
# X movement: 0.0002475619316100741
# Fist detected
# X movement: -0.0001953423023223766
# Fist detected
# X movement: -0.00038091540336609997
# Fist detected
# X movement: 0.0003787577152252197
# Fist detected
# X movement: -7.268786430358887e-05
# Fist detected
# X movement: 0.0005904972553253396
# Fist detected
# X movement: 0.0005848467350005881
# Fist detected
# X movement: 0.0004790604114532915
# Fist detected
# X movement: -0.0005769848823547474
# Fist detected
# X movement: -0.00019603967666625977
# Fist detected
# X movement: -0.00036661624908446155
# Fist detected
# X movement: 0.00010164380073546253
# Fist detected
# X movement: 0.0004625737667083851
# Fist detected
# X movement: 0.0015433251857757124
# Fist detected
# X movement: 0.0017154574394226407
# Fist detected
# X movement: 0.0017740964889526034
# Fist detected
# X movement: 0.001070278882980391
# Fist detected
# X movement: 0.0007814824581146018
# Fist detected
# X movement: -0.0001795351505279319
# Fist detected
# X movement: 0.0005556583404540683
# Fist detected
# X movement: 0.0007212936878204235
# Fist detected
# X movement: 0.0008610188961029053
# Fist detected
# X movement: 0.0008631289005279763
# Fist detected
# X movement: 0.001072704792022705
# Fist detected
# X movement: 2.481937408449486e-05
# Fist detected
# X movement: -0.000285214185714755
# Fist detected
# X movement: -0.0005229532718658558
# Fist detected
# X movement: -0.02541440129280087
# Volume Down triggered
# Fist detected
# X movement: -0.026856923103332542
# Fist detected
# X movement: -0.02723993659019469
# Open palm detected: Play/Pause triggered
# Index finger up detected: Fast forward 5 secs
# Open palm detected: Play/Pause triggered
# Index finger up detected: Fast forward 5 secs
# Fist detected
# Fist detected
# X movement: -0.005585360527038591
# Volume Down triggered
# Fist detected
# X movement: -0.0024379849433898704
# Fist detected
# X movement: 0.005034828186035151
# Fist detected
# X movement: 0.006502249836921686
# Fist detected
# X movement: 0.004621252417564392
# Fist detected
# X movement: 0.005597579479217518
# Volume Up triggered
# Fist detected
# X movement: 0.010189598798751837
# Fist detected
# X movement: 0.01768934726715088
# Open palm detected: Play/Pause triggered
# Fist detected
# Fist detected
# X movement: 0.01740022897720339
# Volume Up triggered
# Fist detected
# X movement: 0.014901912212371804
# Fist detected
# X movement: 0.013014817237854026
# Fist detected
# X movement: 0.00030868053436278187
# Fist detected
# X movement: -0.0010234951972961648
# Fist detected
# X movement: -0.0012005984783172718
# Fist detected
# X movement: -0.004389911890029907
# Fist detected
# X movement: -0.006356906890869096
# Volume Down triggered
# Fist detected
# X movement: -0.00652738213539128
# Fist detected
# X movement: -0.006927347183227517
# Fist detected
# X movement: -0.007575553655624401
# Fist detected
# X movement: -0.009336203336715698
# Volume Down triggered
# Fist detected
# X movement: -0.008436739444732666
# Fist detected
# X movement: -0.016853928565979004
# Fist detected
# X movement: -0.016494119167327848
# Fist detected
# X movement: -0.01852676868438724
# Fist detected
# X movement: -0.011138153076171886
# Volume Down triggered
# Fist detected
# X movement: -0.015204823017120339
# Fist detected
# X movement: -0.007064181566238392
# Fist detected
# X movement: -0.007951003313064586
# Fist detected
# X movement: -0.0027208447456359974
# Fist detected
# X movement: -0.002535128593444791
# Fist detected
# X movement: 0.0015631675720214622
# Fist detected
# X movement: 0.0006223380565643089
# Fist detected
# X movement: 0.001666522026062045
# Fist detected
# X movement: -0.0009940862655639648
# Fist detected
# X movement: -0.0008451342582702637
# Index finger up detected: Fast forward 5 secs
# Open palm detected: Play/Pause triggered
# Index finger up detected: Fast forward 5 secs
# Index finger up detected: Fast forward 5 secs
# Fist detected
# Fist detected
# X movement: -0.0011448681354522816
# Fist detected
# X movement: -0.0030644118785858043
# Fist detected
# X movement: -0.001338922977447532
# Fist detected
# X movement: -0.0018511176109313743
# Fist detected
# X movement: -6.588101387022816e-05
# Fist detected
# X movement: 0.001658821105956998
# Fist detected
# X movement: 0.0012392580509186235
# Fist detected
# X movement: 0.001351809501647927
# Open palm detected: Play/Pause triggered
# Index finger up detected: Fast forward 5 secs
# Index finger up detected: Fast forward 5 secs
# Index finger up detected: Fast forward 5 secs
# Index finger up detected: Fast forward 5 secs
# Open palm detected: Play/Pause triggered
# Thumb down detected: Rewind 5 secs
# Thumb down detected: Rewind 5 secs
# Thumb down detected: Rewind 5 secs
# Thumb down detected: Rewind 5 secs
# Thumb down detected: Rewind 5 secs
# Thumb down detected: Rewind 5 secs
# Index finger up detected: Fast forward 5 secs
# Index finger up detected: Fast forward 5 secs
# Index finger up detected: Fast forward 5 secs
# Index finger up detected: Fast forward 5 secs
# Index finger up detected: Fast forward 5 secs
# Index finger up detected: Fast forward 5 secs
# Index finger up detected: Fast forward 5 secs
# Index finger up detected: Fast forward 5 secs
# Index finger up detected: Fast forward 5 secs
# Index finger up detected: Fast forward 5 secs
# Fist detected
# Fist detected
# X movement: 0.0007411420345306285
# Index finger up detected: Fast forward 5 secs
# Index finger up detected: Fast forward 5 secs
# Open palm detected: Play/Pause triggered
# Fist detected
# Fist detected
# X movement: -0.003951853513717685
# Fist detected
# X movement: -0.0009599089622497337
# Fist detected
# X movement: 0.0019560635089874157
# Fist detected
# X movement: 0.0027508437633514404
# Fist detected
# X movement: 0.0019597113132476807
# Fist detected
# X movement: 0.0005107223987579346
# Fist detected
# X movement: 6.350278854372338e-05
# Fist detected
# X movement: 0.00048035383224487305
# Fist detected
# X movement: 0.001295828819274869
# Fist detected
# X movement: 0.000390470027923584
# Fist detected
# X movement: 4.9173831939697266e-05
# Fist detected
# X movement: 0.000433468818664573
# Fist detected
# X movement: 0.0002626061439514049
# Fist detected
# X movement: -0.0009249269962310902
# Fist detected
# X movement: 0.00010635852813722924
# Fist detected
# X movement: -3.9988756179831775e-05
# Fist detected
# X movement: -0.00014172196388240188
# Fist detected
# X movement: -0.00015329122543339402
# Fist detected
# X movement: 0.003309959173202537
# Fist detected
# X movement: 0.002793473005294811
# Fist detected
# X movement: 0.003683322668075528
# Fist detected
# X movement: 0.003667038679122936
# Fist detected
# X movement: 0.0032917261123657227
# Fist detected
# X movement: 0.0003893613815307839
# Fist detected
# X movement: 0.006133705377578735
# Volume Up triggered
# Index finger up detected: Fast forward 5 secs
# Open palm detected: Play/Pause triggered
# Thumb down detected: Rewind 5 secs
# Thumb down detected: Rewind 5 secs
# Thumb down detected: Rewind 5 secs
# Thumb down detected: Rewind 5 secs
# Thumb down detected: Rewind 5 secs
# Thumb down detected: Rewind 5 secs
# Quitting program
