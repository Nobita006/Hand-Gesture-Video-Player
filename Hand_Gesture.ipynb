# %%
pip install opencv-python mediapipe pyautogui
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: opencv-python in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (4.10.0.84)
# Requirement already satisfied: mediapipe in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (0.10.14)
# Requirement already satisfied: pyautogui in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (0.9.54)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from opencv-python) (2.0.1)
# Requirement already satisfied: absl-py in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from mediapipe) (2.1.0)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from mediapipe) (24.2.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from mediapipe) (24.3.25)
# Requirement already satisfied: jax in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from mediapipe) (0.4.31)
# Requirement already satisfied: jaxlib in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from mediapipe) (0.4.31)
# Requirement already satisfied: matplotlib in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from mediapipe) (3.9.2)
# Requirement already satisfied: opencv-contrib-python in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from mediapipe) (4.10.0.84)
# Requirement already satisfied: protobuf<5,>=4.25.3 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from mediapipe) (4.25.4)
# Requirement already satisfied: sounddevice>=0.4.4 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from mediapipe) (0.5.0)
# Requirement already satisfied: pymsgbox in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from pyautogui) (1.0.9)
# Requirement already satisfied: pytweening>=1.0.4 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from pyautogui) (1.2.0)
# Requirement already satisfied: pyscreeze>=0.1.21 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from pyautogui) (0.1.30)
# Requirement already satisfied: pygetwindow>=0.0.5 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from pyautogui) (0.0.9)
# Requirement already satisfied: mouseinfo in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from pyautogui) (0.1.3)
# Requirement already satisfied: pyrect in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from pygetwindow>=0.0.5->pyautogui) (0.2.0)
# Requirement already satisfied: CFFI>=1.0 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from sounddevice>=0.4.4->mediapipe) (1.17.0)
# Requirement already satisfied: ml-dtypes>=0.2.0 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from jax->mediapipe) (0.4.0)
# Requirement already satisfied: opt-einsum in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from jax->mediapipe) (3.3.0)
# Requirement already satisfied: scipy>=1.10 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from jax->mediapipe) (1.14.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mediapipe) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mediapipe) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mediapipe) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\sayan\appdata\roaming\python\python312\site-packages (from matplotlib->mediapipe) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mediapipe) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mediapipe) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sayan\appdata\roaming\python\python312\site-packages (from matplotlib->mediapipe) (2.9.0.post0)
# Requirement already satisfied: pyperclip in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from mouseinfo->pyautogui) (1.9.0)
# Requirement already satisfied: pycparser in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.22)
# Requirement already satisfied: six>=1.5 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.16.0)
# [notice] A new release of pip is available: 24.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Import Libraries and Set Up Hand Detection

# %%
import cv2
import mediapipe as mp
import pyautogui
import time
import numpy as np
from collections import deque

# Initialize Mediapipe hand detection with higher confidence thresholds
mp_hands = mp.solutions.hands
hands = mp_hands.Hands(max_num_hands=1, min_detection_confidence=0.8, min_tracking_confidence=0.8)
mp_draw = mp.solutions.drawing_utils

# Variables for delay management
last_play_pause_time = time.time()
last_volume_change_time = time.time()
last_gesture_time = time.time()

# Thresholds
play_pause_delay = 1  # 1 second delay for play/pause
volume_change_delay = 0.2  # 1/5 second delay for volume change
gesture_delay = 1  # 1 second delay for gestures
movement_threshold = 0.005  # adjust threshold for detecting meaningful fist movements

# Gesture States
is_open_palm = False
is_fist = False
previous_fist_position = None

# Frame rate control
target_fps = 24
frame_duration = 1.0 / target_fps

# Smoothing settings
smoothing_window_size = 5
landmark_queue = deque(maxlen=smoothing_window_size)

# Capture video from webcam
cap = cv2.VideoCapture(0)

def is_open_palm_landmarks(landmarks):
    return landmarks[8][1] < landmarks[6][1] and \
           landmarks[12][1] < landmarks[10][1] and \
           landmarks[16][1] < landmarks[14][1] and \
           landmarks[20][1] < landmarks[18][1]

def is_fist_landmarks(landmarks):
    return landmarks[8][1] > landmarks[6][1] and \
           landmarks[12][1] > landmarks[10][1] and \
           landmarks[16][1] > landmarks[14][1] and \
           landmarks[20][1] > landmarks[18][1]

def is_index_finger_pointing_up(landmarks):
    return landmarks[8][1] < landmarks[6][1] and \
           landmarks[12][1] > landmarks[10][1] and \
           landmarks[16][1] > landmarks[14][1] and \
           landmarks[20][1] > landmarks[18][1]

def is_thumb_down(landmarks):
    return landmarks[4][1] > landmarks[3][1] and \
           landmarks[8][1] < landmarks[6][1] and \
           landmarks[12][1] < landmarks[10][1] and \
           landmarks[16][1] < landmarks[14][1] and \
           landmarks[20][1] < landmarks[18][1]

def get_fist_direction(current_position, previous_position):
    if current_position is not None and previous_position is not None:
        x_movement = current_position[0] - previous_position[0]
        print(f"X movement: {x_movement}")  # Debugging: print movement amount
        if abs(x_movement) > movement_threshold:
            if x_movement < 0:
                print("Fist moved left")
                return "left"
            elif x_movement > 0:
                print("Fist moved right")
                return "right"
    return None

def smooth_landmarks(landmarks):
    landmark_queue.append(landmarks)
    avg_landmarks = np.mean(landmark_queue, axis=0)
    return avg_landmarks

# %% [markdown]
# Capture Video and Detect Gestures

# %%
while cap.isOpened():
    start_time = time.time()

    success, frame = cap.read()
    if not success:
        print("Failed to capture frame")
        break
    
    # Convert the image to RGB
    image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    image.flags.writeable = False
    
    # Process the image and detect hands
    results = hands.process(image)
    image.flags.writeable = True
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    
    if results.multi_hand_landmarks:
        for hand_landmarks in results.multi_hand_landmarks:
            # Convert landmarks to numpy array for smoothing
            landmarks_array = np.array([(lm.x, lm.y, lm.z) for lm in hand_landmarks.landmark])
            
            # Smooth the landmarks
            smoothed_landmarks = smooth_landmarks(landmarks_array)
            
            # Check if the hand is open palm
            if is_open_palm_landmarks(smoothed_landmarks):
                if not is_open_palm and (time.time() - last_play_pause_time) > play_pause_delay:
                    print("Open palm detected: Play/Pause triggered")
                    pyautogui.press('space')
                    last_play_pause_time = time.time()
                    is_open_palm = True
                is_fist = False  # Reset fist status
            else:
                is_open_palm = False
            
            # Check if the hand is in a fist
            if is_fist_landmarks(smoothed_landmarks):
                print("Fist detected")
                current_position = smoothed_landmarks[9]  # Use landmark 9 as reference for fist position
                if is_fist and previous_fist_position is not None:
                    direction = get_fist_direction(current_position, previous_fist_position)
                    if direction == "left" and (time.time() - last_volume_change_time) > volume_change_delay:
                        print("Volume Down triggered")
                        pyautogui.press('volumedown')
                        last_volume_change_time = time.time()
                    elif direction == "right" and (time.time() - last_volume_change_time) > volume_change_delay:
                        print("Volume Up triggered")
                        pyautogui.press('volumeup')
                        last_volume_change_time = time.time()
                is_fist = True
                previous_fist_position = current_position  # Update the previous fist position
            else:
                is_fist = False

            # Check for index finger pointing up
            if is_index_finger_pointing_up(smoothed_landmarks) and (time.time() - last_gesture_time) > gesture_delay:
                print("Index finger up detected: Fast forward 5 secs")
                pyautogui.press('right')
                last_gesture_time = time.time()

            # Check for thumb down
            if is_thumb_down(smoothed_landmarks) and (time.time() - last_gesture_time) > gesture_delay:
                print("Thumb down detected: Rewind 5 secs")
                pyautogui.press('left')
                last_gesture_time = time.time()

            # Draw hand landmarks
            mp_draw.draw_landmarks(image, hand_landmarks, mp_hands.HAND_CONNECTIONS)
    
    # Display the video feed
    cv2.imshow('Hand Gesture Control', image)
    
    # Break loop with 'q' key
    if cv2.waitKey(1) & 0xFF == ord('q'):
        print("Quitting program")
        break

    # Frame rate control
    end_time = time.time()
    elapsed_time = end_time - start_time
    if elapsed_time < frame_duration:
        time.sleep(frame_duration - elapsed_time)

cap.release()
cv2.destroyAllWindows()
# Out:
# Open palm detected: Play/Pause triggered
# Fist detected
# Fist detected
# X movement: 0.0015330374240875022
# Fist detected
# X movement: 0.0013322591781616544
# Fist detected
# X movement: -0.00041545629501343884
# Fist detected
# X movement: 0.000706571340560902
# Fist detected
# X movement: 0.0005161106586456521
# Fist detected
# X movement: 0.00046147704124449573
# Fist detected
# X movement: 0.00038645267486570045
# Fist detected
# X movement: 0.0007330954074860063
# Fist detected
# X movement: 0.00026322007179258033
# Fist detected
# X movement: 0.00022191405296323463
# Fist detected
# X movement: 0.0002357780933380238
# Fist detected
# X movement: 0.00032692551612856224
# Fist detected
# X movement: 7.396340370174892e-05
# Fist detected
# X movement: 6.920099258422852e-05
# Fist detected
# X movement: 5.302429199222081e-05
# Fist detected
# X movement: 5.787611007668225e-06
# Fist detected
# X movement: -2.714991569519043e-05
# Fist detected
# X movement: 9.119510650634766e-05
# Fist detected
# X movement: 0.00022279620170595482
# Fist detected
# X movement: 0.0001834094524383323
# Fist detected
# X movement: 0.00016646385192869984
# Fist detected
# X movement: 0.0005104601383209562
# Fist detected
# X movement: 0.00046445131301880993
# Fist detected
# X movement: 0.000330507755279541
# Fist detected
# X movement: 0.0003987610340118186
# Fist detected
# X movement: 8.573532104494408e-05
# Fist detected
# X movement: -0.0002981543540954701
# Fist detected
# X movement: -0.00030661821365357556
# Fist detected
# X movement: -0.00024297237396242455
# Fist detected
# X movement: -0.00044155120849609375
# Fist detected
# X movement: -2.0819902420032843e-05
# Fist detected
# X movement: 2.487897872927025e-05
# Fist detected
# X movement: -3.3855438232421875e-05
# Fist detected
# X movement: 0.00021345019340512916
# Fist detected
# X movement: 0.00035179853439332165
# Fist detected
# X movement: 0.00025321245193482556
# Fist detected
# X movement: 0.0002527952194213978
# Fist detected
# X movement: 0.00036315321922297805
# Fist detected
# X movement: 0.00011775493621829503
# Fist detected
# X movement: 0.00044423341751098633
# Fist detected
# X movement: 0.0003973364830017201
# Fist detected
# X movement: 0.0005858480930328036
# Fist detected
# X movement: 0.0003233492374420388
# Fist detected
# X movement: 0.00030895471572872646
# Fist detected
# X movement: -0.0001858353614807018
# Fist detected
# X movement: -1.358985900867804e-06
# Fist detected
# X movement: -0.0002080380916595348
# Fist detected
# X movement: -6.885528564454235e-05
# Fist detected
# X movement: 7.770061492917701e-05
# Fist detected
# X movement: 6.686449050907761e-05
# Fist detected
# X movement: -0.007931548357009932
# Fist moved left
# Volume Down triggered
# Fist detected
# X movement: -0.003399872779846158
# Fist detected
# X movement: -0.003547078371048007
# Fist detected
# X movement: -0.0013240158557891735
# Fist detected
# X movement: -0.0003884255886077992
# Fist detected
# X movement: 0.007415241003036532
# Fist moved right
# Volume Up triggered
# Fist detected
# X movement: 0.0025581359863280917
# Fist detected
# X movement: 0.0026578843593597634
# Fist detected
# X movement: 0.0007479190826416016
# Fist detected
# X movement: -0.00019854307174682617
# Fist detected
# X movement: -1.4919042587269171e-05
# Fist detected
# X movement: 0.0008584797382354403
# Fist detected
# X movement: 0.0006763517856598344
# Fist detected
# X movement: 0.0005283355712890625
# Fist detected
# X movement: 0.0008090674877166415
# Fist detected
# X movement: 0.0007492542266845925
# Fist detected
# X movement: 0.0005021989345550537
# Fist detected
# X movement: 0.00029857754707335316
# Fist detected
# X movement: 6.700754165650524e-05
# Fist detected
# X movement: 5.2964687347389905e-05
# Fist detected
# X movement: -0.0002190709114074374
# Fist detected
# X movement: -0.0005546808242797852
# Fist detected
# X movement: -0.00016051530838012695
# Fist detected
# X movement: -0.0002345561981201283
# Fist detected
# X movement: -0.00037577152252199486
# Fist detected
# X movement: 4.899501800548212e-06
# Fist detected
# X movement: -6.206035614014782e-05
# Fist detected
# X movement: -0.00012782812118528053
# Fist detected
# X movement: -2.7406215667713507e-05
# Fist detected
# X movement: 8.38935375213623e-05
# Fist detected
# X movement: -0.00015664100646972656
# Fist detected
# X movement: -3.084540367126465e-05
# Fist detected
# X movement: -8.864998817448289e-05
# Fist detected
# X movement: -0.0002108335494994673
# Fist detected
# X movement: -0.00023704767227172852
# Fist detected
# X movement: 1.1086463928222656e-05
# Fist detected
# X movement: -0.0009212195873260498
# Fist detected
# X movement: -0.0010550916194915771
# Fist detected
# X movement: -0.001068818569183394
# Fist detected
# X movement: -0.0019450068473815807
# Fist detected
# X movement: -0.0024749338626861572
# Fist detected
# X movement: -0.001415497064590432
# Fist detected
# X movement: -0.0011774420738220326
# Fist detected
# X movement: -0.0026522159576415905
# Fist detected
# X movement: -0.0016149699687957875
# Fist detected
# X movement: -0.0036046147346496804
# Fist detected
# X movement: -0.003799265623092629
# Fist detected
# X movement: -0.004966026544570901
# Fist detected
# X movement: -0.003247773647308383
# Fist detected
# X movement: -0.003453594446182262
# Fist detected
# X movement: -0.0010089337825774924
# Fist detected
# X movement: -0.0031902194023132324
# Fist detected
# X movement: -0.0017698645591736062
# Fist detected
# X movement: -0.00183918476104733
# Fist detected
# X movement: -0.004132711887359641
# Fist detected
# X movement: -0.006661224365234364
# Fist moved left
# Volume Down triggered
# Fist detected
# X movement: -0.006636810302734386
# Fist moved left
# Fist detected
# X movement: -0.006166416406631459
# Fist moved left
# Fist detected
# X movement: -0.006464019417762756
# Fist moved left
# Fist detected
# X movement: -0.006672161817550648
# Fist moved left
# Fist detected
# X movement: -0.0036290824413299783
# Fist detected
# X movement: -0.0011604696512222124
# Fist detected
# X movement: -0.0049287259578705
# Fist detected
# X movement: -0.006988281011581415
# Fist moved left
# Volume Down triggered
# Fist detected
# X movement: -0.003727796673774708
# Fist detected
# X movement: -0.006179767847061174
# Fist moved left
# Fist detected
# X movement: -0.0063064813613891435
# Fist moved left
# Fist detected
# X movement: -0.004741391539573675
# Fist detected
# X movement: -0.0038426965475082397
# Fist detected
# X movement: -0.004098853468894964
# Fist detected
# X movement: -0.0023075163364410234
# Fist detected
# X movement: -0.0034818083047866988
# Fist detected
# X movement: -0.0018030256032943726
# Fist detected
# X movement: -0.0005006492137908936
# Fist detected
# X movement: -0.0021197319030761552
# Fist detected
# X movement: -0.0020322591066360696
# Fist detected
# X movement: -0.0012780487537383811
# Fist detected
# X movement: -0.001180228590965282
# Fist detected
# X movement: -0.0011683732271194347
# Fist detected
# X movement: 0.0016829222440719604
# Fist detected
# X movement: 0.0016425341367721502
# Fist detected
# X movement: 0.0018751323223114014
# Fist detected
# X movement: 0.0018841117620468084
# Fist detected
# X movement: 0.004271027445793163
# Fist detected
# X movement: 0.0050785481929779
# Fist moved right
# Volume Up triggered
# Fist detected
# X movement: 0.008693763613700861
# Fist moved right
# Fist detected
# X movement: 0.00848059356212616
# Fist moved right
# Fist detected
# X movement: 0.007974615693092352
# Fist moved right
# Fist detected
# X movement: 0.008599719405174261
# Fist moved right
# Fist detected
# X movement: 0.006374981999397261
# Fist moved right
# Fist detected
# X movement: 0.0024449050426483265
# Fist detected
# X movement: 0.005428704619407643
# Fist moved right
# Volume Up triggered
# Fist detected
# X movement: 0.009516909718513517
# Fist moved right
# Fist detected
# X movement: 0.006142750382423401
# Fist moved right
# Fist detected
# X movement: 0.0055837929248809814
# Fist moved right
# Fist detected
# X movement: 0.00957249104976654
# Fist moved right
# Fist detected
# X movement: 0.00875468254089351
# Fist moved right
# Volume Up triggered
# Fist detected
# X movement: 0.007771176099777233
# Fist moved right
# Fist detected
# X movement: 0.007821828126907349
# Fist moved right
# Fist detected
# X movement: 0.008210957050323486
# Fist moved right
# Fist detected
# X movement: 0.0072897374629974365
# Fist moved right
# Fist detected
# X movement: 0.008933210372924827
# Fist moved right
# Volume Up triggered
# Fist detected
# X movement: 0.008439767360687245
# Fist moved right
# Fist detected
# X movement: 0.008295899629592873
# Fist moved right
# Fist detected
# X movement: 0.008188509941101096
# Fist moved right
# Fist detected
# X movement: 0.008889389038085949
# Fist moved right
# Fist detected
# X movement: 0.00474947094917294
# Fist detected
# X movement: 0.0025497913360595925
# Fist detected
# X movement: 0.00622796416282656
# Fist moved right
# Volume Up triggered
# Fist detected
# X movement: 0.0068913638591766024
# Fist moved right
# Fist detected
# X movement: 0.0051033973693847545
# Fist moved right
# Fist detected
# X movement: 0.005416256189346325
# Fist moved right
# Fist detected
# X movement: 0.0053588151931762695
# Fist moved right
# Fist detected
# X movement: 0.0030197501182556152
# Fist detected
# X movement: 0.0029446840286255216
# Fist detected
# X movement: 0.0011886477470397505
# Fist detected
# X movement: 0.0015100121498108354
# Fist detected
# X movement: 0.0016090869903564453
# Fist detected
# X movement: 0.000665795803070024
# Fist detected
# X movement: 0.00020388364791873448
# Fist detected
# X movement: 0.0002442181110381969
# Fist detected
# X movement: 0.0003195643424988015
# Fist detected
# X movement: 0.00019872188568115234
# Fist detected
# X movement: 9.608864784238502e-05
# Fist detected
# X movement: 0.000522226095199585
# Fist detected
# X movement: -2.7167797088611945e-05
# Fist detected
# X movement: -0.00046479105949404076
# Fist detected
# X movement: -0.0005242347717285267
# Fist detected
# X movement: -0.00020510554313657448
# Fist detected
# X movement: -0.0014449417591094749
# Fist detected
# X movement: -0.0012136399745941162
# Open palm detected: Play/Pause triggered
# Index finger up detected: Fast forward 5 secs
# Index finger up detected: Fast forward 5 secs
# Index finger up detected: Fast forward 5 secs
# Index finger up detected: Fast forward 5 secs
# Index finger up detected: Fast forward 5 secs
# Open palm detected: Play/Pause triggered
# Thumb down detected: Rewind 5 secs
# Thumb down detected: Rewind 5 secs
# Thumb down detected: Rewind 5 secs
# Thumb down detected: Rewind 5 secs
# Thumb down detected: Rewind 5 secs
# Thumb down detected: Rewind 5 secs
# Thumb down detected: Rewind 5 secs
# Thumb down detected: Rewind 5 secs
# Thumb down detected: Rewind 5 secs
# Thumb down detected: Rewind 5 secs
# Thumb down detected: Rewind 5 secs
# Thumb down detected: Rewind 5 secs
# Open palm detected: Play/Pause triggered
# Fist detected
# Fist detected
# X movement: 0.001773226261138905
# Fist detected
# X movement: 0.001034635305404652
# Fist detected
# X movement: 0.0007825613021850697
# Fist detected
# X movement: 0.001104241609573342
# Fist detected
# X movement: 0.0015547394752502552
# Fist detected
# X movement: 0.0014884114265442117
# Fist detected
# X movement: 0.0018788576126098633
# Fist detected
# X movement: -0.0010344982147216797
# Fist detected
# X movement: -0.00023640990257267624
# Fist detected
# X movement: 0.0008202493190765381
# Fist detected
# X movement: 0.001132631301879905
# Fist detected
# X movement: 0.0016254305839538685
# Fist detected
# X movement: 0.0012136876583099254
# Fist detected
# X movement: 0.0020837843418121116
# Fist detected
# X movement: 0.0004809081554413286
# Fist detected
# X movement: 0.000853973627090443
# Fist detected
# X movement: 0.0006393969058990367
# Fist detected
# X movement: 0.0016207158565521018
# Fist detected
# X movement: 0.0003869891166687345
# Fist detected
# X movement: 0.0011208832263946422
# Fist detected
# X movement: 0.00076271891593932
# Fist detected
# X movement: 0.001444619894027721
# Fist detected
# X movement: 0.0006476938724517822
# Fist detected
# X movement: 0.0006322562694549561
# Fist detected
# X movement: 0.0008064746856689675
# Fist detected
# X movement: 0.001043248176574696
# Fist detected
# X movement: 0.0005173087120056152
# Fist detected
# X movement: 0.000509613752365079
# Fist detected
# X movement: 0.0004952669143676869
# Fist detected
# X movement: 0.00023206472396852806
# Fist detected
# X movement: 9.155273437477796e-06
# Fist detected
# X movement: -0.000124162435531594
# Fist detected
# X movement: -0.0003030955791473722
# Fist detected
# X movement: -0.00019322633743285023
# Fist detected
# X movement: -0.0004008173942565696
# Fist detected
# X movement: -0.00031849145889284447
# Fist detected
# X movement: -7.417798042297363e-05
# Fist detected
# X movement: 6.769299507142224e-05
# Fist detected
# X movement: -2.052187919615589e-05
# Fist detected
# X movement: 0.00013791322708128773
# Fist detected
# X movement: 0.00016646385192869984
# Fist detected
# X movement: 0.0001462996006011963
# Fist detected
# X movement: -2.831816673276588e-05
# Fist detected
# X movement: -3.0404329299960065e-05
# Fist detected
# X movement: -0.0014752686023711825
# Fist detected
# X movement: -0.0012069404125213956
# Fist detected
# X movement: -0.0014918625354766735
# Fist detected
# X movement: -0.0019165813922881747
# Fist detected
# X movement: -0.001975029706954956
# Fist detected
# X movement: -0.0005384862422943559
# Fist detected
# X movement: -0.0010085105895996094
# Fist detected
# X movement: -0.0012723922729491743
# Fist detected
# X movement: -0.0005061268806457742
# Fist detected
# X movement: -0.00041597485542299584
# Fist detected
# X movement: -0.00034415721893310547
# Fist detected
# X movement: -0.00083210468292233
# Fist detected
# X movement: -0.0006179630756378285
# Fist detected
# X movement: -0.000724273920059193
# Fist detected
# X movement: -0.0008201718330383412
# Fist detected
# X movement: -0.0008196294307708518
# Fist detected
# X movement: -0.00022909045219421387
# Fist detected
# X movement: 0.003570383787155129
# Fist detected
# X movement: 0.0023743987083434948
# Fist detected
# X movement: 0.006644743680953968
# Fist moved right
# Volume Up triggered
# Fist detected
# X movement: 0.014316642284393333
# Fist moved right
# Fist detected
# X movement: 0.013870710134506248
# Fist moved right
# Fist detected
# X movement: 0.010024672746658303
# Fist moved right
# Fist detected
# X movement: 0.01665409207344054
# Fist moved right
# Fist detected
# X movement: 0.016225421428680442
# Fist moved right
# Volume Up triggered
# Fist detected
# X movement: 0.012373691797256448
# Fist moved right
# Fist detected
# X movement: 0.012400841712951693
# Fist moved right
# Fist detected
# X movement: 0.01272335052490231
# Fist moved right
# Fist detected
# X movement: 0.00856674909591676
# Fist moved right
# Fist detected
# X movement: 0.004335331916809071
# Fist detected
# X movement: 0.0005451202392578458
# Fist detected
# X movement: 0.0011509537696838268
# Fist detected
# X movement: 0.0013144195079803356
# Fist detected
# X movement: -0.00017040371894838646
# Fist detected
# X movement: 0.0002988576889038086
# Fist detected
# X movement: 6.004571914675072e-05
# Fist detected
# X movement: 7.462501525878906e-05
# Fist detected
# X movement: -0.00018523335456849255
# Fist detected
# X movement: -0.00013236403465272106
# Fist detected
# X movement: -0.00014475584030149147
# Fist detected
# X movement: -0.00013927817344666638
# Fist detected
# X movement: -0.00024983882904050514
# Fist detected
# X movement: -0.0002826511859894132
# Fist detected
# X movement: -0.0013784885406493697
# Fist detected
# X movement: -0.005098599195480391
# Fist moved left
# Volume Down triggered
# Fist detected
# X movement: -0.0077873528003692405
# Fist moved left
# Fist detected
# X movement: -0.008649688959121715
# Fist moved left
# Fist detected
# X movement: -0.008617705106735207
# Fist moved left
# Fist detected
# X movement: -0.010368847846984885
# Fist moved left
# Fist detected
# X movement: -0.007078999280929532
# Fist moved left
# Fist detected
# X movement: -0.004049515724182162
# Fist detected
# X movement: -0.005576616525650002
# Fist moved left
# Volume Down triggered
# Fist detected
# X movement: -0.008825963735580478
# Fist moved left
# Fist detected
# X movement: -0.008747315406799294
# Fist moved left
# Fist detected
# X movement: -0.007948261499404918
# Fist moved left
# Fist detected
# X movement: -0.008226114511489857
# Fist moved left
# Fist detected
# X movement: -0.009330046176910411
# Fist moved left
# Volume Down triggered
# Fist detected
# X movement: -0.005830526351928711
# Fist moved left
# Fist detected
# X movement: -0.0058822810649871715
# Fist moved left
# Fist detected
# X movement: -0.005819481611251842
# Fist moved left
# Fist detected
# X movement: -0.008003175258636475
# Fist moved left
# Fist detected
# X movement: -0.007197737693786621
# Fist moved left
# Volume Down triggered
# Fist detected
# X movement: -0.009051764011383023
# Fist moved left
# Fist detected
# X movement: -0.0052749872207641935
# Fist moved left
# Fist detected
# X movement: -0.0058702051639557
# Fist moved left
# Fist detected
# X movement: -0.0048441648483276145
# Fist detected
# X movement: -0.005219471454620372
# Fist moved left
# Volume Down triggered
# Fist detected
# X movement: -0.005532774329185475
# Fist moved left
# Fist detected
# X movement: -0.0065996289253235085
# Fist moved left
# Fist detected
# X movement: -0.006308820843696578
# Fist moved left
# Fist detected
# X movement: -0.006213808059692377
# Fist moved left
# Fist detected
# X movement: -0.00368488729000091
# Fist detected
# X movement: -0.001414975523948675
# Fist detected
# X movement: -0.0024009525775909313
# Fist detected
# X movement: -0.004122379422187822
# Fist detected
# X movement: -0.0032021880149841198
# Fist detected
# X movement: -0.0026740163564682173
# Fist detected
# X movement: -0.005809751152992232
# Fist moved left
# Volume Down triggered
# Fist detected
# X movement: -0.005257633328437816
# Fist moved left
# Fist detected
# X movement: -0.0037749946117401068
# Fist detected
# X movement: -0.00292783379554748
# Fist detected
# X movement: -0.004809567332267756
# Fist detected
# X movement: -0.0035864144563675093
# Fist detected
# X movement: -0.0034825682640075573
# Fist detected
# X movement: -0.0029788672924041804
# Fist detected
# X movement: -0.004204425215721119
# Fist detected
# X movement: -0.0023595958948135487
# Fist detected
# X movement: 0.0012668728828430231
# Fist detected
# X movement: 0.0009530156850814653
# Fist detected
# X movement: 0.0017084956169128585
# Fist detected
# X movement: 5.027949810026966e-05
# Fist detected
# X movement: 9.601116180421587e-05
# Fist detected
# X movement: -0.0025087982416153176
# Fist detected
# X movement: -0.0016447544097900335
# Fist detected
# X movement: -0.002674192190170288
# Fist detected
# X movement: -0.0005927652120590043
# Fist detected
# X movement: -0.000613784790039068
# Fist detected
# X movement: -0.0011634916067123358
# Fist detected
# X movement: -0.0006441056728363204
# Fist detected
# X movement: -0.0009483337402343694
# Fist detected
# X movement: -0.0006815195083618164
# Fist detected
# X movement: -0.002080878615379339
# Fist detected
# X movement: -0.001366597414016707
# Fist detected
# X movement: -0.0014963686466217263
# Fist detected
# X movement: -0.0016094535589218084
# Fist detected
# X movement: -0.0018584936857223566
# Fist detected
# X movement: -0.0016117304563522117
# Fist detected
# X movement: -0.0015870898962020985
# Fist detected
# X movement: -0.0019778251647949163
# Fist detected
# X movement: -0.004409444332122814
# Fist detected
# X movement: -0.004421380162239058
# Fist detected
# X movement: -0.002795022726058971
# Fist detected
# X movement: -0.0024875879287719616
# Fist detected
# X movement: -0.004186040163040167
# Fist detected
# X movement: -0.0027763783931732122
# Fist detected
# X movement: -0.0036105841398239302
# Fist detected
# X movement: -0.0055581495165824835
# Fist moved left
# Volume Down triggered
# Fist detected
# X movement: -0.0017346441745758057
# Fist detected
# X movement: 0.00042045712471008856
# Fist detected
# X movement: 0.0014126330614089855
# Fist detected
# X movement: 0.0019382089376449585
# Fist detected
# X movement: 0.0033274784684181324
# Fist detected
# X movement: -0.0006537824869155828
# Fist detected
# X movement: -0.0006123870611191018
# Fist detected
# X movement: -0.0002548187971115057
# Fist detected
# X movement: -0.0008739620447158758
# Fist detected
# X movement: -0.004113519191741938
# Fist detected
# X movement: -0.004390935599803941
# Fist detected
# X movement: -0.005864173173904405
# Fist moved left
# Volume Down triggered
# Fist detected
# X movement: -0.004456269741058352
# Fist detected
# X movement: -0.002839998900890345
# Fist detected
# X movement: 0.0014125645160674993
# Fist detected
# X movement: 0.0021288260817527715
# Fist detected
# X movement: 0.003152725100517284
# Fist detected
# X movement: 0.0009333595633506664
# Fist detected
# X movement: 0.00017493665218354382
# Fist detected
# X movement: -0.000304171442985543
# Fist detected
# X movement: -0.0008954450488090487
# Fist detected
# X movement: -0.0010053738951683044
# Fist detected
# X movement: 0.0006209149956703242
# Fist detected
# X movement: 6.874650716781616e-05
# Fist detected
# X movement: -0.0009512513875961359
# Fist detected
# X movement: -0.0008581385016441373
# Fist detected
# X movement: -0.0004158362746238681
# Fist detected
# X movement: -0.0026792228221893255
# Fist detected
# X movement: -0.0011288702487945584
# Fist detected
# X movement: -0.001718199253082281
# Fist detected
# X movement: -0.00018754899501800815
# Fist detected
# X movement: -0.000955910980701441
# Fist detected
# X movement: -0.0006208986043930026
# Fist detected
# X movement: -0.00012481808662415106
# Fist detected
# X movement: 0.0010663598775863675
# Fist detected
# X movement: -9.79304313659668e-05
# Fist detected
# X movement: 0.00010523647069930753
# Quitting program
