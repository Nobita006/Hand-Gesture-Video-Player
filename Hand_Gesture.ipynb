# %%
# %pip install opencv-python mediapipe pyautogui
# Out:
# Requirement already satisfied: opencv-python in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (4.10.0.84)
# Requirement already satisfied: mediapipe in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (0.10.14)
# Requirement already satisfied: pyautogui in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (0.9.54)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from opencv-python) (2.0.1)
# Requirement already satisfied: absl-py in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from mediapipe) (2.1.0)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from mediapipe) (24.2.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from mediapipe) (24.3.25)
# Requirement already satisfied: jax in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from mediapipe) (0.4.31)
# Requirement already satisfied: jaxlib in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from mediapipe) (0.4.31)
# Requirement already satisfied: matplotlib in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from mediapipe) (3.9.2)
# Requirement already satisfied: opencv-contrib-python in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from mediapipe) (4.10.0.84)
# Requirement already satisfied: protobuf<5,>=4.25.3 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from mediapipe) (4.25.4)
# Requirement already satisfied: sounddevice>=0.4.4 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from mediapipe) (0.5.0)
# Requirement already satisfied: pymsgbox in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from pyautogui) (1.0.9)
# Requirement already satisfied: pytweening>=1.0.4 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from pyautogui) (1.2.0)
# Requirement already satisfied: pyscreeze>=0.1.21 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from pyautogui) (0.1.30)
# Requirement already satisfied: pygetwindow>=0.0.5 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from pyautogui) (0.0.9)
# Requirement already satisfied: mouseinfo in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from pyautogui) (0.1.3)
# Requirement already satisfied: pyrect in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from pygetwindow>=0.0.5->pyautogui) (0.2.0)
# Requirement already satisfied: CFFI>=1.0 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from sounddevice>=0.4.4->mediapipe) (1.17.0)
# Requirement already satisfied: ml-dtypes>=0.2.0 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from jax->mediapipe) (0.4.0)
# Requirement already satisfied: opt-einsum in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from jax->mediapipe) (3.3.0)
# Requirement already satisfied: scipy>=1.10 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from jax->mediapipe) (1.14.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mediapipe) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mediapipe) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mediapipe) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\sayan\appdata\roaming\python\python312\site-packages (from matplotlib->mediapipe) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mediapipe) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->mediapipe) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sayan\appdata\roaming\python\python312\site-packages (from matplotlib->mediapipe) (2.9.0.post0)
# Requirement already satisfied: pyperclip in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from mouseinfo->pyautogui) (1.9.0)
# Requirement already satisfied: pycparser in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.22)
# Requirement already satisfied: six>=1.5 in c:\users\sayan\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Import Libraries and Set Up Hand Detection

# %%
import cv2
import mediapipe as mp
import pyautogui
import time
import numpy as np
from collections import deque

# Initialize Mediapipe hand detection with higher confidence thresholds
mp_hands = mp.solutions.hands
hands = mp_hands.Hands(max_num_hands=1, min_detection_confidence=0.8, min_tracking_confidence=0.8)
mp_draw = mp.solutions.drawing_utils

# Variables for delay management
last_play_pause_time = time.time()
last_volume_change_time = time.time()
last_gesture_time = time.time()

# Thresholds
play_pause_delay = 1  # 1 second delay for play/pause
volume_change_delay = 0.2  # 1/5 second delay for volume change
gesture_delay = 1  # 1 second delay for gestures
movement_threshold = 0.005  # adjust threshold for detecting meaningful fist movements

# Gesture States
is_open_palm = False
is_fist = False
previous_fist_position = None
debug_text = ""  # Text to display on the video feed

# Frame rate control
target_fps = 24
frame_duration = 1.0 / target_fps

# Smoothing settings
smoothing_window_size = 5
landmark_queue = deque(maxlen=smoothing_window_size)

# Capture video from webcam
cap = cv2.VideoCapture(0)

def is_open_palm_landmarks(landmarks):
    return landmarks[8][1] < landmarks[6][1] and \
           landmarks[12][1] < landmarks[10][1] and \
           landmarks[16][1] < landmarks[14][1] and \
           landmarks[20][1] < landmarks[18][1]

def is_fist_landmarks(landmarks):
    return landmarks[8][1] > landmarks[6][1] and \
           landmarks[12][1] > landmarks[10][1] and \
           landmarks[16][1] > landmarks[14][1] and \
           landmarks[20][1] > landmarks[18][1]

def is_index_finger_pointing_up(landmarks):
    return landmarks[8][1] < landmarks[6][1] and \
           landmarks[12][1] > landmarks[10][1] and \
           landmarks[16][1] > landmarks[14][1] and \
           landmarks[20][1] > landmarks[18][1]

def is_thumb_down(landmarks):
    return landmarks[4][1] > landmarks[3][1] and \
           landmarks[8][1] < landmarks[6][1] and \
           landmarks[12][1] < landmarks[10][1] and \
           landmarks[16][1] < landmarks[14][1] and \
           landmarks[20][1] < landmarks[18][1]

def get_fist_direction(current_position, previous_position):
    if current_position is not None and previous_position is not None:
        x_movement = current_position[0] - previous_position[0]
        return x_movement
    return None

def smooth_landmarks(landmarks):
    landmark_queue.append(landmarks)
    avg_landmarks = np.mean(landmark_queue, axis=0)
    return avg_landmarks

while cap.isOpened():
    start_time = time.time()

    success, frame = cap.read()
    if not success:
        print("Failed to capture frame")
        break
    
    # Convert the image to RGB
    image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    image.flags.writeable = False
    
    # Process the image and detect hands
    results = hands.process(image)
    image.flags.writeable = True
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    
    if results.multi_hand_landmarks:
        for hand_landmarks in results.multi_hand_landmarks:
            # Convert landmarks to numpy array for smoothing
            landmarks_array = np.array([(lm.x, lm.y, lm.z) for lm in hand_landmarks.landmark])
            
            # Smooth the landmarks
            smoothed_landmarks = smooth_landmarks(landmarks_array)
            
            # Check if the hand is open palm
            if is_open_palm_landmarks(smoothed_landmarks):
                if not is_open_palm and (time.time() - last_play_pause_time) > play_pause_delay:
                    debug_text = "Open palm detected: Play/Pause triggered"
                    print(debug_text)
                    pyautogui.press('space')
                    last_play_pause_time = time.time()
                    is_open_palm = True
                is_fist = False  # Reset fist status
            else:
                is_open_palm = False
            
            # Check if the hand is in a fist
            if is_fist_landmarks(smoothed_landmarks):
                debug_text = "Fist detected"
                print(debug_text)
                current_position = smoothed_landmarks[9]  # Use landmark 9 as reference for fist position
                if is_fist and previous_fist_position is not None:
                    x_movement = get_fist_direction(current_position, previous_fist_position)
                    if x_movement:
                        debug_text = f"X movement: {x_movement}"
                        print(debug_text)
                        if x_movement < -movement_threshold and (time.time() - last_volume_change_time) > volume_change_delay:
                            debug_text = "Volume Down triggered"
                            print(debug_text)
                            pyautogui.press('volumedown')
                            last_volume_change_time = time.time()
                        elif x_movement > movement_threshold and (time.time() - last_volume_change_time) > volume_change_delay:
                            debug_text = "Volume Up triggered"
                            print(debug_text)
                            pyautogui.press('volumeup')
                            last_volume_change_time = time.time()
                is_fist = True
                previous_fist_position = current_position  # Update the previous fist position
            else:
                is_fist = False

            # Check for index finger pointing up
            if is_index_finger_pointing_up(smoothed_landmarks) and (time.time() - last_gesture_time) > gesture_delay:
                debug_text = "Index finger up detected: Fast forward 5 secs"
                print(debug_text)
                pyautogui.press('right')
                last_gesture_time = time.time()

            # Check for thumb down
            if is_thumb_down(smoothed_landmarks) and (time.time() - last_gesture_time) > gesture_delay:
                debug_text = "Thumb down detected: Rewind 5 secs"
                print(debug_text)
                pyautogui.press('left')
                last_gesture_time = time.time()

            # Draw hand landmarks
            mp_draw.draw_landmarks(image, hand_landmarks, mp_hands.HAND_CONNECTIONS)

            # Display the debug text on the video feed
            cv2.putText(image, debug_text, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2, cv2.LINE_AA)
    
    # Display the video feed
    cv2.imshow('Hand Gesture Control', image)
    
    # Break loop with 'q' key
    if cv2.waitKey(1) & 0xFF == ord('q'):
        print("Quitting program")
        break

    # Frame rate control
    end_time = time.time()
    elapsed_time = end_time - start_time
    if elapsed_time < frame_duration:
        time.sleep(frame_duration - elapsed_time)

cap.release()
cv2.destroyAllWindows()
# Out:
# Open palm detected: Play/Pause triggered
# Fist detected
# Fist detected
# X movement: 0.011796790361404408
# Volume Up triggered
# Fist detected
# X movement: 0.01258740425109861
# Fist detected
# X movement: 0.007219409942626986
# Fist detected
# X movement: 0.006997108459472656
# Fist detected
# X movement: 0.0017046451568603072
# Fist detected
# X movement: 0.0011115849018097368
# Fist detected
# X movement: 0.0003500044345855491
# Fist detected
# X movement: 0.0003893911838531716
# Fist detected
# X movement: 0.00041707754135128505
# Fist detected
# X movement: 4.3344497680675165e-05
# Fist detected
# X movement: 0.00029938220977782093
# Fist detected
# X movement: -0.00024382472038270153
# Fist detected
# X movement: -0.0003730654716491699
# Fist detected
# X movement: -0.0007874608039855624
# Fist detected
# X movement: -0.0008064866065979337
# Fist detected
# X movement: -0.0029656589031219482
# Fist detected
# X movement: -0.0025873124599456454
# Fist detected
# X movement: -0.00255584716796875
# Fist detected
# X movement: -0.00539359450340271
# Volume Down triggered
# Fist detected
# X movement: -0.009599119424819946
# Fist detected
# X movement: -0.008118647336959828
# Fist detected
# X movement: -0.008228254318237316
# Fist detected
# X movement: -0.013484090566635132
# Fist detected
# X movement: -0.014800566434860218
# Volume Down triggered
# Fist detected
# X movement: -0.010696101188659712
# Fist detected
# X movement: -0.015480756759643555
# Fist detected
# X movement: -0.015751463174819902
# Fist detected
# X movement: -0.013375633955001853
# Fist detected
# X movement: -0.011518710851669334
# Volume Down triggered
# Fist detected
# X movement: -0.014694663882255543
# Fist detected
# X movement: -0.009483852982521024
# Fist detected
# X movement: -0.009159284830093428
# Fist detected
# X movement: -0.006981238722801181
# Fist detected
# X movement: -0.004456782341003412
# Fist detected
# X movement: -0.0012531250715255848
# Fist detected
# X movement: -0.001188877224922169
# Fist detected
# X movement: -9.116530418407098e-06
# Fist detected
# X movement: 0.0006719082593917847
# Fist detected
# X movement: 0.0008510053157806396
# Fist detected
# X movement: 0.0010113000869750866
# Fist detected
# X movement: 0.0007362335920333973
# Fist detected
# X movement: -0.00042149126529694714
# Fist detected
# X movement: -0.0003789365291595459
# Fist detected
# X movement: 3.3804774284385e-05
# Fist detected
# X movement: 7.497370243070289e-05
# Fist detected
# X movement: 0.0005258202552795577
# Fist detected
# X movement: 0.000363525748252852
# Fist detected
# X movement: 0.002168977260589622
# Fist detected
# X movement: 0.0019358903169631736
# Fist detected
# X movement: 0.0019697636365890725
# Fist detected
# X movement: 0.00647328794002533
# Volume Up triggered
# Fist detected
# X movement: 0.01265575587749479
# Fist detected
# X movement: 0.017181491851806674
# Fist detected
# X movement: 0.016511088609695412
# Fist detected
# X movement: 0.016562968492507935
# Fist detected
# X movement: 0.012072098255157482
# Volume Up triggered
# Fist detected
# X movement: 0.012044686079025257
# Fist detected
# X movement: 0.010278737545013406
# Fist detected
# X movement: 0.01067391037940979
# Fist detected
# X movement: 0.010567826032638561
# Fist detected
# X movement: 0.012837255001068137
# Fist detected
# X movement: 0.0068151235580444225
# Volume Up triggered
# Fist detected
# X movement: 0.003825622797012318
# Fist detected
# X movement: 0.005915290117263827
# Fist detected
# X movement: 0.007776534557342507
# Fist detected
# X movement: 0.0058116912841796875
# Fist detected
# X movement: 0.005791217088699341
# Volume Up triggered
# Fist detected
# X movement: 0.007837754487991344
# Fist detected
# X movement: 0.005988889932632413
# Fist detected
# X movement: 0.007374328374862682
# Fist detected
# X movement: 0.007137477397918701
# Fist detected
# X movement: 0.008189260959625244
# Fist detected
# X movement: 0.004627323150634799
# Fist detected
# X movement: 0.006946706771850553
# Volume Up triggered
# Fist detected
# X movement: 0.004601424932479892
# Fist detected
# X movement: 0.0044845104217529075
# Fist detected
# X movement: 0.003255617618560802
# Fist detected
# X movement: 0.00293825864791869
# Fist detected
# X movement: 0.0003661513328552246
# Fist detected
# X movement: -0.0006122887134552002
# Fist detected
# X movement: -0.0010665476322174183
# Fist detected
# X movement: -0.0019030213356017733
# Fist detected
# X movement: -0.0018935799598693848
# Fist detected
# X movement: -0.0017908334732055775
# Fist detected
# X movement: -0.0026247978210449108
# Fist detected
# X movement: -0.002166569232940674
# Fist detected
# X movement: -0.0011416375637054443
# Fist detected
# X movement: -0.001744574308395419
# Fist detected
# X movement: -0.0016204953193664218
# Fist detected
# X movement: -0.0013535737991333119
# Fist detected
# X movement: -0.0012682080268859863
# Fist detected
# X movement: -0.0012944996356964444
# Fist detected
# X movement: -0.001040154695510831
# Fist detected
# X movement: -0.0023707866668701283
# Fist detected
# X movement: -0.001710909605026234
# Fist detected
# X movement: -0.001792609691619873
# Fist detected
# X movement: -0.0026034891605377086
# Fist detected
# X movement: -0.0019000947475433794
# Fist detected
# X movement: -0.0008162021636962669
# Fist detected
# X movement: -0.0017991602420807107
# Fist detected
# X movement: -0.0019043147563934104
# Fist detected
# X movement: -0.0011110901832580566
# Fist detected
# X movement: -0.0011352479457855114
# Fist detected
# X movement: -0.0010556817054748757
# Fist detected
# X movement: -0.000975227355957009
# Fist detected
# X movement: -0.0017931342124938854
# Fist detected
# X movement: -0.001857852935791049
# Fist detected
# X movement: -0.0019752025604247714
# Fist detected
# X movement: -0.0026274681091308927
# Fist detected
# X movement: -0.0018362462520599143
# Fist detected
# X movement: -0.0009438931941986306
# Fist detected
# X movement: -0.0014996707439422496
# Fist detected
# X movement: -0.0018740296363830566
# Fist detected
# X movement: -0.0012653172016143799
# Fist detected
# X movement: -0.0011824548244476207
# Fist detected
# X movement: -0.001195633411407493
# Fist detected
# X movement: -0.0011465251445770264
# Fist detected
# X movement: -0.0007106542587280162
# Fist detected
# X movement: -0.0005505979061126709
# Fist detected
# X movement: -0.0008768796920776145
# Fist detected
# X movement: -0.00144814252853398
# Fist detected
# X movement: -0.0008744895458221436
# Fist detected
# X movement: -0.0008280932903289573
# Fist detected
# X movement: -0.0008994460105896107
# Fist detected
# X movement: -0.001445329189300515
# Fist detected
# X movement: -0.0006809294223785733
# Fist detected
# X movement: -0.0006420493125915416
# Fist detected
# X movement: -0.001632118225097623
# Fist detected
# X movement: -0.0026827096939087136
# Fist detected
# X movement: -0.0017788290977477916
# Fist detected
# X movement: -0.0019547402858734464
# Fist detected
# X movement: -0.0030949890613555797
# Fist detected
# X movement: -0.002388477325439453
# Fist detected
# X movement: -0.0013070464134216087
# Fist detected
# X movement: -0.0013747692108154186
# Fist detected
# X movement: -0.0019156515598297563
# Fist detected
# X movement: -0.0007241189479827437
# Fist detected
# X movement: -0.0004576742649078369
# Fist detected
# X movement: -0.0006252288818359708
# Fist detected
# X movement: -0.0006238460540771151
# Fist detected
# X movement: -8.702278137207031e-05
# Fist detected
# X movement: -0.0001494288444519043
# Fist detected
# X movement: -0.000587815046310447
# Fist detected
# X movement: -0.0007554471492767223
# Fist detected
# X movement: -0.0007563650608062855
# Fist detected
# X movement: -0.0007248878479003684
# Fist detected
# X movement: -0.0007889986038208119
# Fist detected
# X movement: -0.0010622262954712025
# Fist detected
# X movement: -0.0007553339004516824
# Fist detected
# X movement: -0.000729328393936135
# Fist detected
# X movement: -0.0007434189319610596
# Fist detected
# X movement: -0.0006038188934326394
# Fist detected
# X movement: 7.292628288269043e-05
# Fist detected
# X movement: 6.215572357182175e-05
# Fist detected
# X movement: -0.0002631664276123158
# Fist detected
# X movement: -0.0009721279144287442
# Fist detected
# X movement: -0.0009685993194579745
# Fist detected
# X movement: -0.0010127425193786621
# Fist detected
# X movement: -0.0010100722312927357
# Fist detected
# X movement: -0.0005111813545227162
# Fist detected
# X movement: 0.00015067458152773217
# Fist detected
# X movement: 7.677078247070312e-05
# Fist detected
# X movement: -0.00018167495727539062
# Fist detected
# X movement: -0.00024930238723758213
# Fist detected
# X movement: -0.0005407333374023438
# Fist detected
# X movement: -0.0003669559955596924
# Fist detected
# X movement: -0.00020224452018735573
# Fist detected
# X movement: 9.715557098388672e-05
# Fist detected
# X movement: 0.0001753389835357777
# Fist detected
# X movement: 0.00038953423500059925
# Fist detected
# X movement: 0.0001326441764831765
# Fist detected
# X movement: 1.33514404296875e-05
# Fist detected
# X movement: -6.699562072776111e-06
# Fist detected
# X movement: 0.0004005849361419789
# Fist detected
# X movement: 0.0005523025989532249
# Fist detected
# X movement: 0.0007680058479309082
# Fist detected
# X movement: 0.0006790935993194469
# Fist detected
# X movement: 0.0007212102413177712
# Fist detected
# X movement: 0.0004293680191039817
# Fist detected
# X movement: 0.0002822995185852162
# Fist detected
# X movement: 0.00011178851127624512
# Fist detected
# X movement: 0.001898092031478893
# Fist detected
# X movement: 0.0032380878925323264
# Open palm detected: Play/Pause triggered
# Quitting program
